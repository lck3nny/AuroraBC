# %% [markdown]
# # Scraper 3.2
# ---

# %%
import base64
import os, io
import pytz
import requests
import pandas as pd
from datetime import date, datetime, timedelta
from bs4 import BeautifulSoup
import numpy as np
from math import floor
from pathlib import Path  
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import seaborn as sns
from windrose import WindroseAxes
from PIL import Image
from google.cloud import storage
import google.cloud.logging
import logging
from flask import Response

# %%
from alive_progress import alive_bar

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../service_account.json'

# %%
# -------------------------------------------------------------------------------
# LOGGING SETUP
# -------------------------------------------------------------------------------
client = google.cloud.logging.Client()
client.setup_logging()

# %%
# -------------------------------------------------------------------------------
# CREATE DATERANGE
# -------------------------------------------------------------------------------
def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %% [markdown]
# # Import Dataset
# ---
# Import existing weather data from GoogleCloudStorage as Pandas Dataframe

# %%
# -------------------------------------------------------------------------------
# IMPORT DATASET
# Function to import all weather data
# Data Patching completed in this step
# -------------------------------------------------------------------------------
def import_weather_data():
    # Connect to Google Cloud Storage
    # -------------------------------
    storage_client = storage.Client()

    # Open Bucket
    # -----------
    bucket_name = 'weather_aurorabc'
    bucket = storage_client.bucket(bucket_name)

    # Open Blob
    # ---------
    blob_name = 'weather_ampm.csv'
    #blob_name = 'backups/weather-2023-09-26.csv'
    blob = bucket.blob(blob_name)

    # Read Weather Data from Blob
    # ---------------------------
    with blob.open("r") as f:
        weather_data = pd.read_csv(f)

    # Cast all data variables to float
    weather_data = weather_data.astype(
        {'Height':'float',
        'Temp':'float',
        'Dew_Point':'float',
        'Relative_Humidity':'float',
        'Mixing_Ratio':'float',
        'Wind_Direction':'float',
        'Wind_Speed':'float',
        'Potential_Temp':'float',
        'Equivalent_Potential_Temp':'float',
        'Virtual_Potential_Temp':'float',
        })

    return weather_data

# %% [markdown]
# # Find Missing Values
# ---
# Look through existing dataset and create list of missing data values

# %%
# -------------------------------------------------------------------------------
# FIND MISSING VALS
# Function to find incomplete or missing vals within a dataset
# -------------------------------------------------------------------------------
def find_missing_vals(weather_data, start_date = date(2020, 1, 1), end_date = datetime.today(pytz.timezone("America/Vancouver")).date()):
    missing_data = []
    stations = [
        {"id": 72797, "name": "Quillayute"},
        {"id": 73033, "name": "Vernon"},
        {"id": 71109, "name": "Port Hardy"}]
    pressures = [700, 850]
    dates = daterange(start_date, end_date)
    
    # Loop through all dates from Jan 1st 2020 until today
    # For each date in the range, find the station / pressure / time combinations that are missing
    for i, d in enumerate(dates):
        missing_data.append({
            'date': str(d),
            'stations': []
        })
        for j, s in enumerate(stations):
            # Create empty array of pressures for each station at this date value
            for p in pressures:
                am = weather_data.loc[(weather_data['Date'] == str(d)) & (weather_data['Station'] == str(s['name'])) & (weather_data['Pressure'] == int(p)) & (weather_data['Time'] == 'AM')]
                pm = weather_data.loc[(weather_data['Date'] == str(d)) & (weather_data['Station'] == str(s['name'])) & (weather_data['Pressure'] == int(p)) & (weather_data['Time'] == 'PM')]
                
                
                # If there is no record in the dataset for this date...
                if am.empty or pm.empty:
                    missing_data[i]['stations'].append({'id': s['id'], 'name': s['name'], 'pressures': []}) 
                    missing_data[i]['stations'][-1]['pressures'].append(str(p))
       

                    continue
                
                # If there are null values for Temp or WindSpeed...
                if not am['Temp'].any() or not am['Wind_Speed'].any() or not pm['Temp'].any() or not pm['Wind_Speed'].any():
                    missing_data[i]['stations'].append({'id': s['id'], 'name': s['name'], 'pressures': []}) 
                    missing_data[i]['stations'][-1]['pressures'].append(str(p))
      
    
    
    # Remove unecessary rows where no new data is required
    missing_data = [x for x in missing_data if x['stations']]

    return missing_data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 5
#       1 # -------------------------------------------------------------------------------
#       2 # FIND MISSING VALS
#       3 # Function to find incomplete or missing vals within a dataset
#       4 # -------------------------------------------------------------------------------
# ----> 5 def find_missing_vals(weather_data, start_date = date(2020, 1, 1), end_date = datetime.today(pytz.timezone("America/Vancouver")).date()):
#       6     missing_data = []
#       7     stations = [
#       8         {"id": 72797, "name": "Quillayute"},
#       9         {"id": 73033, "name": "Vernon"},
#      10         {"id": 71109, "name": "Port Hardy"}]
#
# TypeError: datetime.today() takes no arguments (1 given)

# %%
print('US TimeZones')
for timeZone in pytz.country_timezones['CA']:
    print(timeZone)

# %% [markdown]
# # Scrape Data
# ---
# Using a list of incomplete data, generate a list of URLs and scrape.
#
# Return new Dataset in the format of a Pandas Dataframe

# %%
# -------------------------------------------------------------------------------
# SCRAPE DATA
# Itteratively scrape weather balloon data from UWYO site
# Extract 700 and 850 rows from both AM and PM readings
# Return data in Pandas DF
# -------------------------------------------------------------------------------
def scrape_data(missing_vals):
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # GENERATE LIST OF URLS TO BE SCRAPED
    print("Creating list of URLs to be scraped")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    base_url = "http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST"
    times = {'AM': [0, 11], 'PM': [12, 23]}
    
    '''
    x = {
        'date': '2020-01-01', 
        'stations': [
            {'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, 
            {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, 
            {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]
        }
    '''
    
    print("Creating dates list...")

    # Create list of URLs for each station
    # ------------------------------------
    urls = []
    dates_idx = []
    station_idx = []
    for val in missing_vals:
        d = val['date'].split('-')
        for station in val['stations']:
            for t, time in times.items():
                url = base_url
                url += "&YEAR={}".format(d[0])
                url += "&MONTH={}".format(d[1])
                url += "&FROM={:0>2d}{:0>2d}".format(int(d[2]), time[0])
                url += "&TO={:0>2d}{:0>2d}".format(int(d[2]), time[1])
                url += "&STNM={}".format(station["id"])
                url += "&REPLOT=1"
                urls.append(url)

                dates_idx.append("%02d-%02d-%02d" % (int(d[0]), int(d[1]), int(d[2])))
                station_idx.append(station["name"])

    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # EXTRACT DATA FROM URLS
    print("Extracting data from list of URLs")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    #print("Scraping URLS...")
    #print(urls)

    retry = 1
    data = []
    ampm = 0
    problem_urls = []
    with alive_bar(len(urls), force_tty=True) as bar:
        for i, url in enumerate(urls):
            search = 0
            while search >= 0:
                # Scrape site data
                # ~~~~~~~~~~~~~~~~
                search += 1
                page = requests.get(url)
                soup = BeautifulSoup(page.content, "html.parser")
                results = str(soup.find('pre'))
                sevhundy = results[results.find("700"):].split()[:11]
                eightfiddy = results[results.find("850"):].split()[:11]
                

                # Catch erroneous reads
                # Site can hit too many requests
                # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
                if 'e' not in sevhundy[0] and 'e' not in eightfiddy[0]:
                    search = -1
                # Try 3 times then move on
                elif search == retry:
                    print("Could not extract data from: {}".format(url))
                    problem_urls.append(url)
                    search = -1

            # Extract 700 first // 850 second
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            data.append(sevhundy)
            data[-1].insert(0, dates_idx[i])
            data[-1].insert(1, station_idx[i])
            data[-1].insert(2, list(times.keys())[ampm%2])

            data.append(eightfiddy)
            data[-1].insert(0, dates_idx[i])
            data[-1].insert(1, station_idx[i])
            data[-1].insert(2, list(times.keys())[ampm%2])
            
            ampm += 1
                        
            bar()

    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # CLEAN EXTRACTED DATA
    print("Cleaning extracted data")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # Define data cols
    # ----------------
    cols = [
        "Date", 
        "Station", 
        "Time",
        "Pressure", 
        "Height", 
        "Temp", 
        "Dew_Point", 
        "Relative_Humidity", 
        "Mixing_Ratio", 
        "Wind_Direction", 
        "Wind_Speed", 
        "Potential_Temp",
        "Equivalent_Potential_Temp",
        "Virtual_Potential_Temp"]

    # Remove incomplete rows from dataset
    # -----------------------------------
    data = [row for row in data if len(row) >= len(cols)]

    # Remove rogue "e" values from pressure field
    # -------------------------------------------
    pressures = [700, 850]
    ctr = 0
    for item in data:
        if(not str(item[3]).isnumeric()):
            item[3] = pressures[ctr%2]
        ctr += 1

    # Convert data to Pandas DataFrame
    # --------------------------------
    new_data = pd.DataFrame(data, columns=cols)
    return new_data

# %% [markdown]
# # Standardize Datatypes
# ---

# %%
# -------------------------------------------------------------------------------
# STANDARDIZE DATATYPES
# Ensrues each col follows correct data type
# -------------------------------------------------------------------------------
def standardize_dtypes(data):
    return data.astype( dtype={
                'Date' : str, 
                'Station': str,
                'Time': str,
                'Pressure': int,
                'Height': float,
                'Temp': float,
                'Dew_Point': float,
                'Relative_Humidity': float,
                'Mixing_Ratio': float,
                'Wind_Direction': float,
                'Wind_Speed': float,
                'Potential_Temp': float,
                'Equivalent_Potential_Temp': float,
                'Virtual_Potential_Temp': float,
                                      })

# %% [markdown]
# # Patch Dataset
# ---
# Populate missing or incomplete data entries with NaN values

# %%
# -------------------------------------------------------------------------------
# PATCH DATASET
# Function to create empty entries for missing data
# This results in a data entries for each expected date/location/pressure reading
# -------------------------------------------------------------------------------
def patch_dataset(data, start_date=date(2020, 1, 1), end_date=datetime.today(pytz.timezone("America/Vancouver")).date()):

    dates = daterange(start_date, end_date)


    stations = ['Quillayute', 'Vernon', 'Port Hardy']
    times = {'AM': [0, 11], 'PM': [12, 23]}
    pressures = [700, 850]
    idx = len(data)
    # Itterate through date range
    for date in dates:
        for station in stations:
            for t, time in times.items():
                for pressure in pressures:
                    # If data is missing, add empty values
                    if data[(data['Date'] == date.strftime("%Y-%m-%d")) & (data['Station'] == station) & (data['Time'] == t) & (data['Pressure'] == pressure)].empty:
                        #print("Missing data for {}:\n\tDate:{}\n\tPressure:{}\n".format(station, date.strftime("%Y-%m-%d"), pressure))
                        new_row = {
                            'Date': date.strftime("%Y-%m-%d"), 
                            'Station': station, 
                            'Time': t,
                            'Pressure': pressure, 
                            'Height': np.nan,
                            'Temp': np.nan,
                            'Dew_Point': np.nan,
                            'Relative_Humidity': np.nan,
                            'Mixing_Ratio': np.nan,
                            'Wind_Direction': np.nan,
                            'Wind_Speed': np.nan,
                            'Potential_Temp': np.nan,
                            'Equivalent_Potential_Temp': np.nan,
                            'Virtual_Potential_Temp': np.nan}

                        #data.loc[idx] = new_row
                        data.loc[idx] = [date.strftime("%Y-%m-%d"), station, t, pressure, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan]
                        idx += 1
                        #data.loc[-1] = new_row

    # Return complete data
    print("Patching Complete")
    return data.sort_values(by=['Date', 'Station', 'Pressure'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 6
#       1 # -------------------------------------------------------------------------------
#       2 # PATCH DATASET
#       3 # Function to create empty entries for missing data
#       4 # This results in a data entries for each expected date/location/pressure reading
#       5 # -------------------------------------------------------------------------------
# ----> 6 def patch_dataset(data, start_date=date(2020, 1, 1), end_date=datetime.today(pytz.timezone("America/Vancouver")).date()):
#       8     dates = daterange(start_date, end_date)
#      11     stations = ['Quillayute', 'Vernon', 'Port Hardy']
#
# TypeError: datetime.today() takes no arguments (1 given)

# %% [markdown]
# # Upload Complete Dataset
# ---
# Upload a complete dataset to the GoogleCloudStorage bucket and create daily backup

# %%
# -------------------------------------------------------------------------------
# UPLOAD WEATHER DATA
# Saves data to cloud bucket
# -------------------------------------------------------------------------------
def upload_weather_data(data):
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # SAVE DATA TO GOOGLE CLOUD
    print("Saving data to Google Cloud Bucket")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  

    # Connect to Google Cloud Storage
    # -------------------------------
    storage_client = storage.Client()

    # Open Bucket
    # -----------
    bucket_name = 'weather_aurorabc'
    bucket = storage_client.bucket(bucket_name)

    # Save today's backup
    # -------------------
    mybuffer = io.BytesIO()
    data.to_csv(mybuffer, index=False)

    blob = bucket.blob('backups/weather_ampm-{}.csv'.format(datetime.today(pytz.timezone("America/Vancouver")).date()))
    blob.upload_from_string(mybuffer.getvalue())

    # Update weather.csv
    # ------------------
    blob = bucket.blob('weather_ampm.csv')
    blob.upload_from_string(mybuffer.getvalue())

# %% [markdown]
# ---
# # Main
# ---

# %%
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + 
# ----- ----- ----- -----          START         ----- ----- ----- -----
#  + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + 
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#@functions_framework.cloud_event
def main():
    # Import existing weather data from Google Cloud
    # ----------------------------------------------
    weather_data = import_weather_data()
    
    
    # Find missing or 'nan' values within current dataset
    # ---------------------------------------------------
    missing_data = find_missing_vals(weather_data)
    
    
    # Scrape weather balloons for new data within defined date range
    # --------------------------------------------------------------
    new_data = scrape_data(missing_data[-25:])
    
    # Handle NaN values and standardize data types
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    new_data.dropna(subset=['Temp', 'Wind_Speed'])
    new_data = standardize_dtypes(new_data)
    
    # Convert wind speed from Knots to KM/H
    # -------------------------------------
    new_data['Wind_Speed'] = new_data['Wind_Speed'].multiply(1.852)

    
    # Combine existing weather data with newly extracted data
    # -------------------------------------------------------
    complete_data = pd.concat([weather_data, new_data])
    complete_data = complete_data.sort_values(by=['Date', 'Station', 'Time', 'Pressure'])
    
    # Patch dataset with NaN values for any missing fields
    # ----------------------------------------------------
    final_data = patch_dataset(complete_data)
    final_data = final_data.sort_values(by=['Date', 'Station', 'Time', 'Pressure'])
    
    
    # Upload clean data to bucket
    # ---------------------------
    upload_weather_data(complete_data)
    
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + 
# ----- ----- ----- -----           END          ----- ----- ----- -----
#  + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + 
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
main()
# Out:
# Creating list of URLs to be scraped
# Creating dates list...
# Extracting data from list of URLs
# on 2: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=09&FROM=2200&TO=2211&STNM=72797&REPLOT=1
# on 4: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=09&FROM=2200&TO=2211&STNM=72797&REPLOT=1
# on 7: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=09&FROM=2512&TO=2523&STNM=72797&REPLOT=1
# on 9: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=09&FROM=2512&TO=2523&STNM=72797&REPLOT=1
# on 11: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=09&FROM=2612&TO=2623&STNM=73033&REPLOT=1
# on 13: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=09&FROM=2612&TO=2623&STNM=73033&REPLOT=1
# on 16: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=0400&TO=0411&STNM=73033&REPLOT=1
# on 18: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=0400&TO=0411&STNM=73033&REPLOT=1
# on 22: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=1100&TO=1111&STNM=72797&REPLOT=1
# on 23: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=1112&TO=1123&STNM=72797&REPLOT=1
# on 24: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=1100&TO=1111&STNM=72797&REPLOT=1
# on 25: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=1112&TO=1123&STNM=72797&REPLOT=1
# on 30: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=1800&TO=1811&STNM=73033&REPLOT=1
# on 31: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=1812&TO=1823&STNM=73033&REPLOT=1
# on 32: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=1800&TO=1811&STNM=73033&REPLOT=1
# on 33: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=1812&TO=1823&STNM=73033&REPLOT=1
# on 34: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=2000&TO=2011&STNM=73033&REPLOT=1
# on 35: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=2012&TO=2023&STNM=73033&REPLOT=1
# on 36: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=2000&TO=2011&STNM=73033&REPLOT=1
# on 37: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=2012&TO=2023&STNM=73033&REPLOT=1
# on 38: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=2100&TO=2111&STNM=73033&REPLOT=1
# on 39: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=2112&TO=2123&STNM=73033&REPLOT=1
# on 40: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=2100&TO=2111&STNM=73033&REPLOT=1
# on 41: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=2112&TO=2123&STNM=73033&REPLOT=1
# on 42: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=2700&TO=2711&STNM=73033&REPLOT=1
# on 43: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=2712&TO=2723&STNM=73033&REPLOT=1
# on 44: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=2700&TO=2711&STNM=73033&REPLOT=1
# on 45: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=2712&TO=2723&STNM=73033&REPLOT=1
# on 46: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=2900&TO=2911&STNM=73033&REPLOT=1
# on 48: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=2900&TO=2911&STNM=73033&REPLOT=1
# on 50: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=3000&TO=3011&STNM=73033&REPLOT=1
# on 52: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=10&FROM=3000&TO=3011&STNM=73033&REPLOT=1
# on 64: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=11&FROM=0500&TO=0511&STNM=73033&REPLOT=1
# on 65: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=11&FROM=0512&TO=0523&STNM=73033&REPLOT=1
# on 66: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=11&FROM=0500&TO=0511&STNM=73033&REPLOT=1
# on 67: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=11&FROM=0512&TO=0523&STNM=73033&REPLOT=1
# on 68: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=11&FROM=0600&TO=0611&STNM=73033&REPLOT=1
# on 69: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=11&FROM=0612&TO=0623&STNM=73033&REPLOT=1
# on 70: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=11&FROM=0600&TO=0611&STNM=73033&REPLOT=1
# on 71: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=11&FROM=0612&TO=0623&STNM=73033&REPLOT=1
# on 72: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=11&FROM=1800&TO=1811&STNM=72797&REPLOT=1
# on 74: Could not extract data from: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2023&MONTH=11&FROM=1800&TO=1811&STNM=72797&REPLOT=1
# |████████████████████████████████████████| 82/82 [100%] in 2:59.3 (0.45/s)
# Cleaning extracted data
# Patching Complete
# Saving data to Google Cloud Bucket
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 main()
#
# Cell In[42], line 45, in main()
#      40 final_data = final_data.sort_values(by=['Date', 'Station', 'Time', 'Pressure'])
#      43 # Upload clean data to bucket
#      44 # ---------------------------
# ---> 45 upload_weather_data(complete_data)
#
# Cell In[41], line 25, in upload_weather_data(data)
#      22 mybuffer = io.BytesIO()
#      23 data.to_csv(mybuffer, index=False)
# ---> 25 blob = bucket.blob('backups/weather_ampm-{}.csv'.format(datetime.today(pytz.timezone("America/Vancouver")).date()))
#      26 blob.upload_from_string(mybuffer.getvalue())
#      28 # Update weather.csv
#      29 # ------------------
#
# TypeError: datetime.today() takes no arguments (1 given)

# %% [markdown]
# ---
# # END
# ---
