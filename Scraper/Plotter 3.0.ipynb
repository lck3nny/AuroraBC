# %% [markdown]
# # Plotter 3.0

# %%
import base64
import os, io
from datetime import date, datetime, timedelta
import pandas as pd
import seaborn as sns
from windrose import WindroseAxes
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from PIL import Image
import numpy as np
import google.cloud.logging
from google.cloud import storage
import logging
from alive_progress import alive_bar

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../service_account.json'

# %% [markdown]
# ### Create Date Range

# %%
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ----- ----- ----- -----    CREATE DATERANGE    ----- ----- ----- -----
# Create list of all dates between start_date and end_date
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

# ======================================================================

# %% [markdown]
# ### Truncate CMAP

# %%
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ----- ----- ----- -----   TRUNCATE COLORMAP    ----- ----- ----- -----
# Can be used to remove white / black bookended values
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
def truncate_colormap(cmap, minval=0.0, maxval=1.0, n=100):
    new_cmap = colors.LinearSegmentedColormap.from_list(
          'trunc({n},{a:.2f},{b:.2f})'.format(n=cmap.name, a=minval, b=maxval),
          cmap(np.linspace(minval, maxval, n)))
    return new_cmap

# ======================================================================

# %% [markdown]
# ### Import Weather Data

# %%
# -------------------------------------------------------------------------------
# IMPORT DATASET
# Function to import all weather data
# Data Patching completed in this step
# -------------------------------------------------------------------------------
def import_weather_data(storage_client):
    # Connect to Google Cloud Storage
    # -------------------------------
    storage_client = storage.Client()

    # Open Bucket
    # -----------
    bucket_name = 'weather_aurorabc'
    bucket = storage_client.bucket(bucket_name)

    # Open Blob
    # ---------
    blob_name = 'weather_ampm.csv'
    #blob_name = 'backups/weather-2023-09-26.csv'
    blob = bucket.blob(blob_name)

    # Read Weather Data from Blob
    # ---------------------------
    with blob.open("r") as f:
        weather_data = pd.read_csv(f)

    # Cast all data variables to float
    weather_data = weather_data.astype(
        {'Height':'float',
        'Temp':'float',
        'DewPoint':'float',
        'Relative_Humidity':'float',
        'Mean_Mixed_Layer':'float',
        'Wind_Direction':'float',
        'Wind_Speed':'float',
        'Potential_Temp':'float',
        'Equivalent_Potential_Temp':'float',
        'Virtual_Potential_Temp':'float',
        })

    return weather_data

# %% [markdown]
# # Plot Temps
# ---
# Updated function to plot temperature graphs of varying data ranges for a range of dates for individual locations

# %%
def plot_temps(storage_client, location, dates, plot_range):

    for d in dates:
        for r in plot_range:
            
            # Set figure details
            # ~~~~~~~~~~~~~~~~~~
            plt.figure(figsize=(20,6))
            plt.xlim([0, r -1])
            plt.grid()
            plt.axhline(0, color='black')
            plt.xticks(rotation = 'vertical')
            plt.title("Temperature °C - {} day".format(r))
            if r > 30:
                plt.xticks(np.arange(0, r+1, 7.0))

            # Set color palette for the graph
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            palette = sns.color_palette("Paired", n_colors=6)
            palette_order = [1, 0, 3, 2, 5, 4]
            palette = [palette[idx] for idx in palette_order]
            hue_order = [850, 700]


            # Create new df containing only data within plot range
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            mask = (location['data']['Date'] >= str(d - timedelta(days=r))) & (location['data']['Date'] <= str(d))
            plot_data = location['data'].loc[mask]
            
            # Calculate IQR for column Temp
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            Q1 = plot_data['Temp'].quantile(0.10)
            Q3 = plot_data['Temp'].quantile(0.90)
            IQR = Q3 - Q1

            # Identify and remove outliers
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            threshold = 1.5
            outliers = plot_data[(plot_data['Temp'] < Q1 - threshold * IQR) | (plot_data['Temp'] > Q3 + threshold * IQR)]
            plot_data = plot_data.drop(outliers.index)
            
            # Skip plot if there are no numerical values within the subset
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            if plot_data.dropna(subset=['Temp']).empty:
                print("COULD NOT GENERATE GRAPH")
                print("Location: {}".format(location['name']))
                print("Date: {}".format(d))
                print("Plot Range: {}".format(r))
                print("Data: {}\n".format(plot_data))
                continue

            # Plot graph
            # ~~~~~~~~~~
            try:
                g = sns.lineplot(x='Date', y='Temp', hue='Pressure', data=plot_data, palette=palette[location['palette_order'][0]: location['palette_order'][1]], hue_order=hue_order)
            except Exception as e:
                print(e)
                print(plot_data)

            # Rename legend with detailed labels
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            l = plt.legend()
            labels = ['850', '700']
            for x, label in enumerate(labels):
                l.get_texts()[x].set_text(label)
                
            # Define save details
            # ~~~~~~~~~~~~~~~~~~~
            save_name = '{}_temp'.format(location['save_name'])
            save_loc = "./figures/temp/{}".format(d.strftime("%Y-%m-%d"))
            if not os.path.isdir(save_loc):
                os.makedirs(save_loc)
                
            # Publish graph to Google Cloud
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            bucket_name = 'weather_aurorabc'
            bucket = storage_client.bucket(bucket_name)

            buff = io.BytesIO()
            plt.savefig(buff, format='webp',dpi=150, bbox_inches="tight")

            blob_name = 'graphs_test/{}/{}_{}d_{}.webp'.format(d.strftime("%Y-%m-%d"), save_name, r, d.strftime("%Y-%m-%d"))
            blob = bucket.blob(blob_name)
            blob.upload_from_string(buff.getvalue(), content_type='image/png')
            plt.close()
            del buff

# %% [markdown]
# # Plot ALL Temps
# ---
# Updated function to plot temperature graphs of varying data ranges for a range of dates for all locations on a single graph

# %%
def plot_all_temps(storage_client, location, dates, plot_range):
    
    for d in dates:
        for r in plot_range:
            
            # Set figure details
            # ~~~~~~~~~~~~~~~~~~
            plt.figure(figsize=(20,6))
            plt.xlim([0, r -1])
            plt.grid()
            plt.axhline(0, color='black')
            plt.xticks(rotation = 'vertical')
            plt.title("Temperature °C - {} day".format(r))
            if r > 30:
                plt.xticks(np.arange(0, r+1, 7.0))
                
            # Set color palette for the graph
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            palette = sns.color_palette("Paired", n_colors=6)
            palette_order = [1, 0, 3, 2, 5, 4]
            palette = [palette[idx] for idx in palette_order]
            hue_order = [850, 700]
            
            # Loop through each location and plot data on graph
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            for location in locations:
                # Create truncated data object with only correct date range
                # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
                mask = (location['data']['Date'] >= str(d - timedelta(days=r))) & (location['data']['Date'] <= str(d))
                plot_data = location['data'].loc[mask]
                
                # Calculate IQR for column Temp
                # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
                Q1 = plot_data['Temp'].quantile(0.10)
                Q3 = plot_data['Temp'].quantile(0.90)
                IQR = Q3 - Q1
                
                # Identify and remove outliers
                # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~
                threshold = 1.5
                outliers = plot_data[(plot_data['Temp'] < Q1 - threshold * IQR) | (plot_data['Temp'] > Q3 + threshold * IQR)]
                plot_data = plot_data.drop(outliers.index)
                
                # Skip plot if there are no numerical values within the subset
                # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
                if plot_data.dropna(subset=['Temp']).empty:
                    print("COULD NOT GENERATE GRAPH")
                    print("Location: {}".format(location['name']))
                    print("Date: {}".format(d))
                    print("Plot Range: {}".format(r))
                    print("Data: {}\n".format(plot_data))
                    continue

                # Add data for single location to graph
                # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
                g = sns.lineplot(x='Date', y='Temp', hue='Pressure', data=plot_data, palette=palette[location['palette_order'][0]: location['palette_order'][1]], hue_order=hue_order)
                
            
            # Rename legend with detailed labels
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            l = plt.legend()
            labels = []
            for location in locations:
                for pressure in [700, 850]:
                    labels.append('{} {}'.format(location['name'], pressure))
                    
            labels = [labels[idx] for idx in palette_order]
            for x, label in enumerate(labels):
                l.get_texts()[x].set_text(label)
                
            
            # Generate Save Path
            # ~~~~~~~~~~~~~~~~~~
            save_name = 'all_temp'
            save_loc = "./figures/wind/{}".format(d)
            if not os.path.isdir(save_loc):
                os.makedirs(save_loc)
                
                
            # Publish graph to Google Cloud
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            bucket_name = 'weather_aurorabc'
            bucket = storage_client.bucket(bucket_name)

            buff = io.BytesIO()
            plt.savefig(buff, format='webp',dpi=150, bbox_inches="tight")

            blob_name = 'graphs_test/{}/{}_{}d_{}.webp'.format(d.strftime("%Y-%m-%d"), save_name, r, d.strftime("%Y-%m-%d"))
            blob = bucket.blob(blob_name)
            blob.upload_from_string(buff.getvalue(), content_type='image/png')
            plt.close()
            del buff

# %% [markdown]
# # Plot Wind
# ---
# Updated function to plot wind graphs of varying data ranges for a range of dates for individual locations

# %%
def plot_wind(storage_client, location, dates, plot_range):
    
    # Define color map and truncate to apropriate range
    cmap = cm.viridis_r
    cmap = truncate_colormap(cmap, minval=0, maxval=0.9)
    
    for d in dates:
        for r in plot_range:
            
            # Create new df containing only data within plot range
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            mask = (location['data']['Date'] >= str(d - timedelta(days=r))) & (location['data']['Date'] <= str(d))
            plot_data = location['data'].loc[mask]
            
            # Calculate IQR for column Temp
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            Q1 = plot_data['Wind_Speed'].quantile(0.05)
            Q3 = plot_data['Wind_Speed'].quantile(0.95)
            IQR = Q3 - Q1

            # Identify and remove outliers
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            threshold = 1.5
            outliers = plot_data[(plot_data['Wind_Speed'] < Q1 - threshold * IQR) | (plot_data['Wind_Speed'] > Q3 + threshold * IQR)]
            plot_data = plot_data.drop(outliers.index)
            plot_data = plot_data.dropna(subset=['Wind_Speed'])
            
            # Skip plot if there are no numerical values within the subset
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            if plot_data.empty:
                print("COULD NOT GENERATE GRAPH")
                print("Location: {}".format(location['name']))
                print("Date: {}".format(d))
                print("Plot Range: {}".format(r))
                print("Data: {}\n".format(plot_data))
                continue
                
            # Populate speed and direction vars from DataFrame
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  
            wd = plot_data['Wind_Direction'].to_list()
            ws = plot_data['Wind_Speed'].to_list()


            # Plot wind rose for data set
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~
            ax = WindroseAxes.from_ax()
            #ax.contourf(wd, ws, bins=np.arange(0, 100, 10), cmap=cmap)
            ax.contourf(wd, ws, cmap=cmap)
            ax.set_legend()
            
            # Save figure
            # ~~~~~~~~~~~
            plt.title("{} Wind - {} day".format(location['name'], r))
            plt.legend(title="Wind Speed (km/h)", loc=4, fontsize='small', fancybox=True)
            
            # Generate Save Path
            # ~~~~~~~~~~~~~~~~~~
            save_name = '{}_wind'.format(location['name'].lower().replace(' ', ''))
            save_loc = "./figures/wind/{}".format(d)
            
            if not os.path.isdir(save_loc):
                os.makedirs(save_loc)

            # Save image as webp
            # ~~~~~~~~~~~~~~~~~~
            path = '{}/{}_{}d_{}'.format(save_loc, save_name, r, d)
            plt.savefig('{}.webp'.format(path), format='webp',dpi=150)
            
            # Publish graph to Google Cloud
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            bucket_name = 'weather_aurorabc'
            bucket = storage_client.bucket(bucket_name)

            buff = io.BytesIO()
            plt.savefig(buff, format='webp',dpi=150, bbox_inches="tight")

            blob_name = 'graphs_test/{}/{}_{}d_{}.webp'.format(d, save_name, r, d)
            blob = bucket.blob(blob_name)
            blob.upload_from_string(buff.getvalue(), content_type='image/png')
            plt.close()
            del buff

# %% [markdown]
# ### Main Application Body

# %%
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + 
# ----- ----- ----- -----          START         ----- ----- ----- -----
#  + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + 
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

def main():
    # Collect weather data
    # ~~~~~~~~~~~~~~~~~~~~
    storage_client = storage.Client()
    weather_data = import_weather_data(storage_client)

    # Create Date Range
    # ~~~~~~~~~~~~~~~~~
    start_date = datetime(2020, 1, 1)
    end_date = datetime.today()
    dates = []
    for single_date in daterange(start_date, end_date):
        dates.append(single_date.date())
        
    # Define plot ranges
    # ~~~~~~~~~~~~~~~~~~
    plot_range = [3, 5, 10, 30, 90, 180]
    
    # Define location specific params
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    locations = [{
            'name': "Vernon",
            'palette_order': [2, 4], # green
            'save_name': "vernon",
            'data': weather_data[weather_data['Station'] == "Vernon"]
        },
        {
            'name': "Port Hardy",
            'palette_order': [4, 6], # red
            'save_name': "porthardy",
            'data': weather_data[weather_data['Station'] == "Port Hardy"]
        },
        {
            'name': "Quillayute",
            'palette_order': [0, 2], # blue
            'save_name': "quillayute",
            'data': weather_data[weather_data['Station'] == "Quillayute"]
        }]
    
    with alive_bar(len(dates), force_tty=True) as bar:
        for date in dates:
            print('{} --------------------'.format(date))
            print("Plotting ALL Temps")
            plot_all_temps(storage_client, locations, [date], plot_range)

            for location in locations:

                print("Plotting Wind: {}".format(location['name']))
                plot_wind(storage_client, location, [date], plot_range)

                print("Plotting Temp: {}\n".format(location['name']))
                plot_temps(storage_client, location, [date], plot_range)
            bar()
        
    
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + 
# ----- ----- ----- -----           END          ----- ----- ----- -----
#  + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + + 
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
main()
# Out:
# on 0: 2020-01-01 --------------------
# on 0: Plotting ALL Temps
# on 0: Plotting Wind: Vernon
# on 0: Plotting Temp: Vernon
# on 0: Plotting Wind: Port Hardy
# on 0: Plotting Temp: Port Hardy
# on 0: Plotting Wind: Quillayute
# on 0: Plotting Temp: Quillayute
# on 1: 2020-01-02 --------------------
# on 1: Plotting ALL Temps
# on 1: Plotting Wind: Vernon
# on 1: Plotting Temp: Vernon
# on 1: Plotting Wind: Port Hardy
# on 1: Plotting Temp: Port Hardy
# on 1: Plotting Wind: Quillayute
# on 1: Plotting Temp: Quillayute
# on 2: 2020-01-03 --------------------
# on 2: Plotting ALL Temps
# on 2: Plotting Wind: Vernon
# on 2: Plotting Temp: Vernon
# on 2: Plotting Wind: Port Hardy
# on 2: Plotting Temp: Port Hardy
# on 2: Plotting Wind: Quillayute
# on 2: Plotting Temp: Quillayute
# on 3: 2020-01-04 --------------------
# on 3: Plotting ALL Temps
# on 3: Plotting Wind: Vernon
# on 3: Plotting Temp: Vernon
# on 3: Plotting Wind: Port Hardy
# on 3: Plotting Temp: Port Hardy
# on 3: Plotting Wind: Quillayute
# on 3: Plotting Temp: Quillayute
# on 4: 2020-01-05 --------------------
# on 4: Plotting ALL Temps
# on 4: Plotting Wind: Vernon
# on 4: Plotting Temp: Vernon
# on 4: Plotting Wind: Port Hardy
# on 4: Plotting Temp: Port Hardy
# on 4: Plotting Wind: Quillayute
# on 4: Plotting Temp: Quillayute
# on 5: 2020-01-06 --------------------
# on 5: Plotting ALL Temps
# on 5: Plotting Wind: Vernon
# on 5: Plotting Temp: Vernon
# on 5: Plotting Wind: Port Hardy
# on 5: Plotting Temp: Port Hardy
# on 5: Plotting Wind: Quillayute
# on 5: Plotting Temp: Quillayute
# on 6: 2020-01-07 --------------------
# on 6: Plotting ALL Temps
# on 6: Plotting Wind: Vernon
# on 6: Plotting Temp: Vernon
# on 6: Plotting Wind: Port Hardy
# on 6: Plotting Temp: Port Hardy
# on 6: Plotting Wind: Quillayute
# on 6: Plotting Temp: Quillayute
# on 7: 2020-01-08 --------------------
# on 7: Plotting ALL Temps
# on 7: Plotting Wind: Vernon
# on 7: Plotting Temp: Vernon
# on 7: Plotting Wind: Port Hardy
# on 7: Plotting Temp: Port Hardy
# on 7: Plotting Wind: Quillayute
# on 7: Plotting Temp: Quillayute
# on 8: 2020-01-09 --------------------
# on 8: Plotting ALL Temps
# on 8: Plotting Wind: Vernon
# on 8: Plotting Temp: Vernon
# on 8: Plotting Wind: Port Hardy
# on 8: Plotting Temp: Port Hardy
# on 8: Plotting Wind: Quillayute
# on 8: Plotting Temp: Quillayute
# on 9: 2020-01-10 --------------------
# on 9: Plotting ALL Temps
# on 9: Plotting Wind: Vernon
# on 9: Plotting Temp: Vernon
# on 9: Plotting Wind: Port Hardy
# on 9: Plotting Temp: Port Hardy
# on 9: Plotting Wind: Quillayute
# on 9: Plotting Temp: Quillayute
# on 10: 2020-01-11 --------------------
# on 10: Plotting ALL Temps
# on 10: Plotting Wind: Vernon
# on 10: Plotting Temp: Vernon
# on 10: Plotting Wind: Port Hardy
# on 10: Plotting Temp: Port Hardy
# on 10: Plotting Wind: Quillayute
# on 10: Plotting Temp: Quillayute
# on 11: 2020-01-12 --------------------
# on 11: Plotting ALL Temps
# on 11: Plotting Wind: Vernon
# on 11: Plotting Temp: Vernon
# on 11: Plotting Wind: Port Hardy
# on 11: Plotting Temp: Port Hardy
# on 11: Plotting Wind: Quillayute
# on 11: Plotting Temp: Quillayute
# on 12: 2020-01-13 --------------------
# on 12: Plotting ALL Temps
# on 12: Plotting Wind: Vernon
# on 12: Plotting Temp: Vernon
# on 12: Plotting Wind: Port Hardy
# on 12: Plotting Temp: Port Hardy
# on 12: Plotting Wind: Quillayute
# on 12: Plotting Temp: Quillayute
# on 13: 2020-01-14 --------------------
# on 13: Plotting ALL Temps
# on 13: Plotting Wind: Vernon
# on 13: Plotting Temp: Vernon
# on 13: Plotting Wind: Port Hardy
# on 13: Plotting Temp: Port Hardy
# on 13: Plotting Wind: Quillayute
# on 13: Plotting Temp: Quillayute
# on 14: 2020-01-15 --------------------
# on 14: Plotting ALL Temps
# on 14: Plotting Wind: Vernon
# on 14: Plotting Temp: Vernon
# on 14: Plotting Wind: Port Hardy
# on 14: Plotting Temp: Port Hardy
# on 14: Plotting Wind: Quillayute
# on 14: Plotting Temp: Quillayute
# on 15: 2020-01-16 --------------------
# on 15: Plotting ALL Temps
# on 15: Plotting Wind: Vernon
# on 15: Plotting Temp: Vernon
# on 15: Plotting Wind: Port Hardy
# on 15: Plotting Temp: Port Hardy
# on 15: Plotting Wind: Quillayute
# on 15: Plotting Temp: Quillayute
# on 16: 2020-01-17 --------------------
# on 16: Plotting ALL Temps
# on 16: Plotting Wind: Vernon
# on 16: Plotting Temp: Vernon
# on 16: Plotting Wind: Port Hardy
# on 16: Plotting Temp: Port Hardy
# on 16: Plotting Wind: Quillayute
# on 16: Plotting Temp: Quillayute
# on 17: 2020-01-18 --------------------
# on 17: Plotting ALL Temps
# on 17: Plotting Wind: Vernon
# on 17: Plotting Temp: Vernon
# on 17: Plotting Wind: Port Hardy
# on 17: Plotting Temp: Port Hardy
# on 17: Plotting Wind: Quillayute
# on 17: Plotting Temp: Quillayute
# on 18: 2020-01-19 --------------------
# on 18: Plotting ALL Temps
# on 18: Plotting Wind: Vernon
# on 18: Plotting Temp: Vernon
# on 18: Plotting Wind: Port Hardy
# on 18: Plotting Temp: Port Hardy
# on 18: Plotting Wind: Quillayute
# on 18: Plotting Temp: Quillayute
# on 19: 2020-01-20 --------------------
# on 19: Plotting ALL Temps
# on 19: Plotting Wind: Vernon
# on 19: Plotting Temp: Vernon
# on 19: Plotting Wind: Port Hardy
# on 19: Plotting Temp: Port Hardy
# on 19: Plotting Wind: Quillayute
# on 19: Plotting Temp: Quillayute
# on 20: 2020-01-21 --------------------
# on 20: Plotting ALL Temps
# on 20: Plotting Wind: Vernon
# on 20: Plotting Temp: Vernon
# on 20: Plotting Wind: Port Hardy
# on 20: Plotting Temp: Port Hardy
# on 20: Plotting Wind: Quillayute
# on 20: Plotting Temp: Quillayute
# on 21: 2020-01-22 --------------------
# on 21: Plotting ALL Temps
# on 21: Plotting Wind: Vernon
# on 21: Plotting Temp: Vernon
# on 21: Plotting Wind: Port Hardy
# on 21: Plotting Temp: Port Hardy
# on 21: Plotting Wind: Quillayute
# on 21: Plotting Temp: Quillayute
# on 22: 2020-01-23 --------------------
# on 22: Plotting ALL Temps
# on 22: Plotting Wind: Vernon
# on 22: Plotting Temp: Vernon
# on 22: Plotting Wind: Port Hardy
# on 22: Plotting Temp: Port Hardy
# on 22: Plotting Wind: Quillayute
# on 22: Plotting Temp: Quillayute
# on 23: 2020-01-24 --------------------
# on 23: Plotting ALL Temps
# on 23: Plotting Wind: Vernon
# on 23: Plotting Temp: Vernon
# on 23: Plotting Wind: Port Hardy
# on 23: Plotting Temp: Port Hardy
# on 23: Plotting Wind: Quillayute
# on 23: Plotting Temp: Quillayute
# on 24: 2020-01-25 --------------------
# on 24: Plotting ALL Temps
# on 24: Plotting Wind: Vernon
# on 24: Plotting Temp: Vernon
# on 24: Plotting Wind: Port Hardy
# on 24: Plotting Temp: Port Hardy
# on 24: Plotting Wind: Quillayute
# on 24: Plotting Temp: Quillayute
# on 25: 2020-01-26 --------------------
# on 25: Plotting ALL Temps
# on 25: Plotting Wind: Vernon
# on 25: Plotting Temp: Vernon
# on 25: Plotting Wind: Port Hardy
# on 25: Plotting Temp: Port Hardy
# on 25: Plotting Wind: Quillayute
# on 25: Plotting Temp: Quillayute
# on 26: 2020-01-27 --------------------
# on 26: Plotting ALL Temps
# on 26: Plotting Wind: Vernon
# on 26: Plotting Temp: Vernon
# on 26: Plotting Wind: Port Hardy
# on 26: Plotting Temp: Port Hardy
# on 26: Plotting Wind: Quillayute
# on 26: Plotting Temp: Quillayute
# on 27: 2020-01-28 --------------------
# on 27: Plotting ALL Temps
# on 27: Plotting Wind: Vernon
# on 27: Plotting Temp: Vernon
# on 27: Plotting Wind: Port Hardy
# on 27: Plotting Temp: Port Hardy
# on 27: Plotting Wind: Quillayute
# on 27: Plotting Temp: Quillayute
# on 28: 2020-01-29 --------------------
# on 28: Plotting ALL Temps
# on 28: Plotting Wind: Vernon
# on 28: Plotting Temp: Vernon
# on 28: Plotting Wind: Port Hardy
# on 28: Plotting Temp: Port Hardy
# on 28: Plotting Wind: Quillayute
# on 28: Plotting Temp: Quillayute
# on 29: 2020-01-30 --------------------
# on 29: Plotting ALL Temps
# on 29: Plotting Wind: Vernon
# on 29: Plotting Temp: Vernon
# on 29: Plotting Wind: Port Hardy
# on 29: Plotting Temp: Port Hardy
# on 29: Plotting Wind: Quillayute
# on 29: Plotting Temp: Quillayute
# on 30: 2020-01-31 --------------------
# on 30: Plotting ALL Temps
# on 30: Plotting Wind: Vernon
# on 30: Plotting Temp: Vernon
# on 30: Plotting Wind: Port Hardy
# on 30: Plotting Temp: Port Hardy
# on 30: Plotting Wind: Quillayute
# on 30: Plotting Temp: Quillayute
# on 31: 2020-02-01 --------------------
# on 31: Plotting ALL Temps
# on 31: Plotting Wind: Vernon
# on 31: Plotting Temp: Vernon
# on 31: Plotting Wind: Port Hardy
# on 31: Plotting Temp: Port Hardy
# on 31: Plotting Wind: Quillayute
# on 31: Plotting Temp: Quillayute
# on 32: 2020-02-02 --------------------
# on 32: Plotting ALL Temps
# on 32: Plotting Wind: Vernon
# on 32: Plotting Temp: Vernon
# on 32: Plotting Wind: Port Hardy
# on 32: Plotting Temp: Port Hardy
# on 32: Plotting Wind: Quillayute
# on 32: Plotting Temp: Quillayute
# on 33: 2020-02-03 --------------------
# on 33: Plotting ALL Temps
# on 33: Plotting Wind: Vernon
# on 33: Plotting Temp: Vernon
# on 33: Plotting Wind: Port Hardy
# on 33: Plotting Temp: Port Hardy
# on 33: Plotting Wind: Quillayute
# on 33: Plotting Temp: Quillayute
# on 34: 2020-02-04 --------------------
# on 34: Plotting ALL Temps
# on 34: Plotting Wind: Vernon
# on 34: Plotting Temp: Vernon
# on 34: Plotting Wind: Port Hardy
# on 34: Plotting Temp: Port Hardy
# on 34: Plotting Wind: Quillayute
# on 34: Plotting Temp: Quillayute
# on 35: 2020-02-05 --------------------
# on 35: Plotting ALL Temps
# on 35: Plotting Wind: Vernon
# on 35: Plotting Temp: Vernon
# on 35: Plotting Wind: Port Hardy
# on 35: Plotting Temp: Port Hardy
# on 35: Plotting Wind: Quillayute
# on 35: Plotting Temp: Quillayute
# on 36: 2020-02-06 --------------------
# on 36: Plotting ALL Temps
# on 36: Plotting Wind: Vernon
# on 36: Plotting Temp: Vernon
# on 36: Plotting Wind: Port Hardy
# on 36: Plotting Temp: Port Hardy
# on 36: Plotting Wind: Quillayute
# on 36: Plotting Temp: Quillayute
# on 37: 2020-02-07 --------------------
# on 37: Plotting ALL Temps
# on 37: Plotting Wind: Vernon
# on 37: Plotting Temp: Vernon
# on 37: Plotting Wind: Port Hardy
# on 37: Plotting Temp: Port Hardy
# on 37: Plotting Wind: Quillayute
# on 37: Plotting Temp: Quillayute
# on 38: 2020-02-08 --------------------
# on 38: Plotting ALL Temps
# on 38: Plotting Wind: Vernon
# on 38: Plotting Temp: Vernon
# on 38: Plotting Wind: Port Hardy
# on 38: Plotting Temp: Port Hardy
# on 38: Plotting Wind: Quillayute
# on 38: Plotting Temp: Quillayute
# on 39: 2020-02-09 --------------------
# on 39: Plotting ALL Temps
# on 39: Plotting Wind: Vernon
# on 39: Plotting Temp: Vernon
# on 39: Plotting Wind: Port Hardy
# on 39: Plotting Temp: Port Hardy
# on 39: Plotting Wind: Quillayute
# on 39: Plotting Temp: Quillayute
# on 40: 2020-02-10 --------------------
# on 40: Plotting ALL Temps
# on 40: Plotting Wind: Vernon
# on 40: Plotting Temp: Vernon
# on 40: Plotting Wind: Port Hardy
# on 40: Plotting Temp: Port Hardy
# on 40: Plotting Wind: Quillayute
# on 40: Plotting Temp: Quillayute
# on 41: 2020-02-11 --------------------
# on 41: Plotting ALL Temps
# on 41: Plotting Wind: Vernon
# on 41: Plotting Temp: Vernon
# on 41: Plotting Wind: Port Hardy
# on 41: Plotting Temp: Port Hardy
# on 41: Plotting Wind: Quillayute
# on 41: Plotting Temp: Quillayute
# on 42: 2020-02-12 --------------------
# on 42: Plotting ALL Temps
# on 42: Plotting Wind: Vernon
# on 42: Plotting Temp: Vernon
# on 42: Plotting Wind: Port Hardy
# on 42: Plotting Temp: Port Hardy
# on 42: Plotting Wind: Quillayute
# on 42: Plotting Temp: Quillayute
# on 43: 2020-02-13 --------------------
# on 43: Plotting ALL Temps
# on 43: Plotting Wind: Vernon
# on 43: Plotting Temp: Vernon
# on 43: Plotting Wind: Port Hardy
# on 43: Plotting Temp: Port Hardy
# on 43: Plotting Wind: Quillayute
# on 43: Plotting Temp: Quillayute
# on 44: 2020-02-14 --------------------
# on 44: Plotting ALL Temps
# on 44: Plotting Wind: Vernon
# on 44: Plotting Temp: Vernon
# on 44: Plotting Wind: Port Hardy
# on 44: Plotting Temp: Port Hardy
# on 44: Plotting Wind: Quillayute
# on 44: Plotting Temp: Quillayute
# on 45: 2020-02-15 --------------------
# on 45: Plotting ALL Temps
# on 45: Plotting Wind: Vernon
# on 45: Plotting Temp: Vernon
# on 45: Plotting Wind: Port Hardy
# on 45: Plotting Temp: Port Hardy
# on 45: Plotting Wind: Quillayute
# on 45: Plotting Temp: Quillayute
# on 46: 2020-02-16 --------------------
# on 46: Plotting ALL Temps
# on 46: Plotting Wind: Vernon
# on 46: Plotting Temp: Vernon
# on 46: Plotting Wind: Port Hardy
# on 46: Plotting Temp: Port Hardy
# on 46: Plotting Wind: Quillayute
# on 46: Plotting Temp: Quillayute
# on 47: 2020-02-17 --------------------
# on 47: Plotting ALL Temps
# on 47: Plotting Wind: Vernon
# on 47: Plotting Temp: Vernon
# on 47: Plotting Wind: Port Hardy
# on 47: Plotting Temp: Port Hardy
# on 47: Plotting Wind: Quillayute
# on 47: Plotting Temp: Quillayute
# on 48: 2020-02-18 --------------------
# on 48: Plotting ALL Temps
# on 48: Plotting Wind: Vernon
# on 48: Plotting Temp: Vernon
# on 48: Plotting Wind: Port Hardy
# on 48: Plotting Temp: Port Hardy
# on 48: Plotting Wind: Quillayute
# on 48: Plotting Temp: Quillayute
# on 49: 2020-02-19 --------------------
# on 49: Plotting ALL Temps
# on 49: Plotting Wind: Vernon
# on 49: Plotting Temp: Vernon
# on 49: Plotting Wind: Port Hardy
# on 49: Plotting Temp: Port Hardy
# on 49: Plotting Wind: Quillayute
# on 49: Plotting Temp: Quillayute
# on 50: 2020-02-20 --------------------
# on 50: Plotting ALL Temps
# on 50: Plotting Wind: Vernon
# on 50: Plotting Temp: Vernon
# on 50: Plotting Wind: Port Hardy
# on 50: Plotting Temp: Port Hardy
# on 50: Plotting Wind: Quillayute
# on 50: Plotting Temp: Quillayute
# on 51: 2020-02-21 --------------------
# on 51: Plotting ALL Temps
# on 51: Plotting Wind: Vernon
# on 51: Plotting Temp: Vernon
# on 51: Plotting Wind: Port Hardy
# on 51: Plotting Temp: Port Hardy
# on 51: Plotting Wind: Quillayute
# on 51: Plotting Temp: Quillayute
# on 52: 2020-02-22 --------------------
# on 52: Plotting ALL Temps
# on 52: Plotting Wind: Vernon
# on 52: Plotting Temp: Vernon
# on 52: Plotting Wind: Port Hardy
# on 52: Plotting Temp: Port Hardy
# on 52: Plotting Wind: Quillayute
# on 52: Plotting Temp: Quillayute
# on 53: 2020-02-23 --------------------
# on 53: Plotting ALL Temps
# on 53: Plotting Wind: Vernon
# on 53: Plotting Temp: Vernon
# on 53: Plotting Wind: Port Hardy
# on 53: Plotting Temp: Port Hardy
# on 53: Plotting Wind: Quillayute
# on 53: Plotting Temp: Quillayute
# on 54: 2020-02-24 --------------------
# on 54: Plotting ALL Temps
# on 54: Plotting Wind: Vernon
# on 54: Plotting Temp: Vernon
# on 54: Plotting Wind: Port Hardy
# on 54: Plotting Temp: Port Hardy
# on 54: Plotting Wind: Quillayute
# on 54: Plotting Temp: Quillayute
# on 55: 2020-02-25 --------------------
# on 55: Plotting ALL Temps
# on 55: Plotting Wind: Vernon
# on 55: Plotting Temp: Vernon
# on 55: Plotting Wind: Port Hardy
# on 55: Plotting Temp: Port Hardy
# on 55: Plotting Wind: Quillayute
# on 55: Plotting Temp: Quillayute
# on 56: 2020-02-26 --------------------
# on 56: Plotting ALL Temps
# on 56: Plotting Wind: Vernon
# on 56: Plotting Temp: Vernon
# on 56: Plotting Wind: Port Hardy
# on 56: Plotting Temp: Port Hardy
# on 56: Plotting Wind: Quillayute
# on 56: Plotting Temp: Quillayute
# on 57: 2020-02-27 --------------------
# on 57: Plotting ALL Temps
# on 57: Plotting Wind: Vernon
# on 57: Plotting Temp: Vernon
# on 57: Plotting Wind: Port Hardy
# on 57: Plotting Temp: Port Hardy
# on 57: Plotting Wind: Quillayute
# on 57: Plotting Temp: Quillayute
# on 58: 2020-02-28 --------------------
# on 58: Plotting ALL Temps
# on 58: Plotting Wind: Vernon
# on 58: Plotting Temp: Vernon
# on 58: Plotting Wind: Port Hardy
# on 58: Plotting Temp: Port Hardy
# on 58: Plotting Wind: Quillayute
# on 58: Plotting Temp: Quillayute
# on 59: 2020-02-29 --------------------
# on 59: Plotting ALL Temps
# on 59: Plotting Wind: Vernon
# on 59: Plotting Temp: Vernon
# on 59: Plotting Wind: Port Hardy
# on 59: Plotting Temp: Port Hardy
# on 59: Plotting Wind: Quillayute
# on 59: Plotting Temp: Quillayute
# on 60: 2020-03-01 --------------------
# on 60: Plotting ALL Temps
# on 60: Plotting Wind: Vernon
# on 60: Plotting Temp: Vernon
# on 60: Plotting Wind: Port Hardy
# on 60: Plotting Temp: Port Hardy
# on 60: Plotting Wind: Quillayute
# on 60: Plotting Temp: Quillayute
# on 61: 2020-03-02 --------------------
# on 61: Plotting ALL Temps
# on 61: Plotting Wind: Vernon
# on 61: Plotting Temp: Vernon
# on 61: Plotting Wind: Port Hardy
# on 61: Plotting Temp: Port Hardy
# on 61: Plotting Wind: Quillayute
# on 61: Plotting Temp: Quillayute
# on 62: 2020-03-03 --------------------
# on 62: Plotting ALL Temps
# on 62: Plotting Wind: Vernon
# on 62: Plotting Temp: Vernon
# on 62: Plotting Wind: Port Hardy
# on 62: Plotting Temp: Port Hardy
# |█▊                                      | ▄▆█ 62/1424 [4%] in 27:13 (~9:57:09, 0.0/s)

# %%
# Create function to find missing graphs
# Create function to plot all temps together
# Create function to plot wind --- DONE

# %%
# Plotting Temps Error
# missing data is removed and therefore so are x axis entries
# can this wait until other issues are resolved?
