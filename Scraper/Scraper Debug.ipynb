# %%
import base64
import os, io
import requests
import pandas as pd
from datetime import date, datetime, timedelta
from bs4 import BeautifulSoup
import numpy as np
from math import floor
from pathlib import Path  
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import seaborn as sns
from windrose import WindroseAxes
from PIL import Image
from google.cloud import storage
import google.cloud.logging
import logging
from flask import Response

# %%
from alive_progress import alive_bar

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../service_account.json'

# %%
# -------------------------------------------------------------------------------
# LOGGING SETUP
# -------------------------------------------------------------------------------
client = google.cloud.logging.Client()
client.setup_logging()

# %%
# -------------------------------------------------------------------------------
# CREATE DATERANGE
# -------------------------------------------------------------------------------
def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %%
# -------------------------------------------------------------------------------
# PATCH DATASET
# Function to create empty entries for missing data
# This results in a data entries for each expected date/location/pressure reading
# -------------------------------------------------------------------------------
def patch_dataset(data, start_date, end_date):
    dates = daterange(start_date, end_date)


    stations = ['Quillayute', 'Vernon', 'Port Hardy']
    pressures = [700, 850]
    idx = len(data)
    # Itterate through date range
    for date in dates:
        for station in stations:
            for pressure in pressures:
                # If data is missing, add empty values
                if data[(data['Date'] == date.strftime("%Y-%m-%d")) & (data['Station'] == station) & (data['Pressure'] == pressure)].empty:
                    #print("Missing data for {}:\n\tDate:{}\n\tPressure:{}\n".format(station, date.strftime("%Y-%m-%d"), pressure))
                    new_row = {
                        'Date': date.strftime("%Y-%m-%d"), 
                        'Station': station, 
                        'Pressure': pressure, 
                        'Height': np.nan,
                        'Temp': np.nan,
                        'DewPoint': np.nan,
                        'Relative_Humidity': np.nan,
                        'Mean_Mixed_Layer': np.nan,
                        'Wind_Direction': np.nan,
                        'Wind_Speed': np.nan,
                        'Potential_Temp': np.nan,
                        'Equivalent_Potential_Temp': np.nan,
                        'Virtual_Potential_Temp': np.nan}

                    data.loc[idx] = new_row
                    idx += 1
                    #data.loc[-1] = new_row

    # Return complete data
    print("Patching Complete")
    return data.sort_values(by=['Date', 'Station', 'Pressure'])

# %%
# -------------------------------------------------------------------------------
# IMPORT DATASET
# Function to import all weather data
# Data Patching completed in this step
# -------------------------------------------------------------------------------
def import_weather_data():
    # Connect to Google Cloud Storage
    # -------------------------------
    storage_client = storage.Client()

    # Open Bucket
    # -----------
    bucket_name = 'weather_aurorabc'
    bucket = storage_client.bucket(bucket_name)

    # Open Blob
    # ---------
    blob_name = 'weather.csv'
    #blob_name = 'backups/weather-2023-09-26.csv'
    blob = bucket.blob(blob_name)

    # Read Weather Data from Blob
    # ---------------------------
    with blob.open("r") as f:
        weather_data = pd.read_csv(f)

    # Cast all data variables to float
    weather_data = weather_data.astype(
        {'Height':'float',
        'Temp':'float',
        'DewPoint':'float',
        'Relative_Humidity':'float',
        'Mean_Mixed_Layer':'float',
        'Wind_Direction':'float',
        'Wind_Speed':'float',
        'Potential_Temp':'float',
        'Equivalent_Potential_Temp':'float',
        'Virtual_Potential_Temp':'float',
        })

    return weather_data

# %%
# -------------------------------------------------------------------------------
# UPLOAD WEATHER DATA
# Saves data to cloud bucket
# -------------------------------------------------------------------------------
def upload_weather_data(data):
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # SAVE DATA TO GOOGLE CLOUD
    print("Saving data to Google Cloud Bucket")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  

    # Connect to Google Cloud Storage
    # -------------------------------
    storage_client = storage.Client()

    # Open Bucket
    # -----------
    bucket_name = 'weather_aurorabc'
    bucket = storage_client.bucket(bucket_name)

    # Save today's backup
    # -------------------
    mybuffer = io.BytesIO()
    data.to_csv(mybuffer, index=False)

    blob = bucket.blob('backups/weather-{}.csv'.format(datetime.today().date()))
    blob.upload_from_string(mybuffer.getvalue())

    # Update weather.csv
    # ------------------
    blob = bucket.blob('weather.csv')
    blob.upload_from_string(mybuffer.getvalue())

# %%
def scrape_data(dates):
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # GENERATE LIST OF URLS TO BE SCRAPED
    print("Creating list of URLs to be scraped")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    base_url = "http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST"

    stations = [
        {"id": 72797, "name": "Quillayute"},
        {"id": 73033, "name": "Vernon"},
        {"id": 71109, "name": "Port Hardy"}]

    print("Creating dates list...")

    # Create list of URLs for each station
    # ------------------------------------
    urls = []
    dates_idx = []
    station_idx = []
    for d in dates:
        d = d.split('-')
        for station in stations:
            url = base_url
            url += "&YEAR={}".format(d[0])
            url += "&MONTH={}".format(d[1])
            #url += "&FROM=" + str(now[1]) + str(now[2])
            #url += "&TO=" + str(now[1]) + str(now[2])
            url += "&FROM={:0>2d}00".format(int(d[2]))
            url += "&TO={:0>2d}23".format(int(d[2]))
            url += "&STNM={}".format(station["id"])
            url += "&REPLOT=1"
            urls.append(url)

            dates_idx.append("%02d-%02d-%02d" % (int(d[0]), int(d[1]), int(d[2])))
            station_idx.append(station["name"])

    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # EXTRACT DATA FROM URLS
    print("Extracting data from list of URLs")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    #print("Scraping URLS...")
    #print(urls)


    data = []
    problem_urls = []
    for i, url in enumerate(urls):
        search = 0
        while search >= 0:
            # Scrape site data
            # ~~~~~~~~~~~~~~~~
            search += 1
            page = requests.get(url)
            soup = BeautifulSoup(page.content, "html.parser")
            results = str(soup.find('pre'))
            sevhundy = results[results.find("700"):].split()[:11]
            eightfiddy = results[results.find("850"):].split()[:11]

            # Catch erroneous reads
            # Site can hit too many requests
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            if 'e' not in sevhundy[0] and 'e' not in eightfiddy[0]:
                search = -1
            elif search == 10:
                print(url)
                problem_urls.append(url)
                search = -1

        # Extract 700 first // 850 second
        # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
        data.append(sevhundy)
        data[-1].insert(0, dates_idx[i])
        data[-1].insert(1, station_idx[i])

        data.append(eightfiddy)
        data[-1].insert(0, dates_idx[i])
        data[-1].insert(1, station_idx[i])

    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # CLEAN EXTRACTED DATA
    print("Cleaning extracted data")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # Define data cols
    # ----------------
    cols = ["Date", 
        "Station", 
        "Pressure", 
        "Height", 
        "Temp", 
        "DewPoint", 
        "Relative_Humidity", 
        "Mean_Mixed_Layer", 
        "Wind_Direction", 
        "Wind_Speed", 
        "Potential_Temp",
        "Equivalent_Potential_Temp",
        "Virtual_Potential_Temp"]

    # Remove incomplete rows from dataset
    # -----------------------------------
    data = [row for row in data if len(row) >= len(cols)]

    # Remove rogue "e" values from pressure field
    # -------------------------------------------
    pressures = [700, 850]
    ctr = 0
    for item in data:
        if(not str(item[2]).isnumeric()):
            item[2] = pressures[ctr%2]
        ctr += 1

    # Convert data to Pandas DataFrame
    # --------------------------------
    new_data = pd.DataFrame(data, columns=cols)
    return new_data

# %%
def scrape_data_2(missing_vals):
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # GENERATE LIST OF URLS TO BE SCRAPED
    print("Creating list of URLs to be scraped")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    base_url = "http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST"

    '''
    x = {
        'date': '2020-01-01', 
        'stations': [
            {'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, 
            {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, 
            {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]
        }
    '''
    print("Creating dates list...")

    # Create list of URLs for each station
    # ------------------------------------
    urls = []
    dates_idx = []
    station_idx = []
    for val in missing_vals:
        d = val['date'].split('-')
        for station in val['stations']:
            url = base_url
            url += "&YEAR={}".format(d[0])
            url += "&MONTH={}".format(d[1])
            #url += "&FROM=" + str(now[1]) + str(now[2])
            #url += "&TO=" + str(now[1]) + str(now[2])
            url += "&FROM={:0>2d}00".format(int(d[2]))
            url += "&TO={:0>2d}23".format(int(d[2]))
            url += "&STNM={}".format(station["id"])
            url += "&REPLOT=1"
            urls.append(url)

            dates_idx.append("%02d-%02d-%02d" % (int(d[0]), int(d[1]), int(d[2])))
            station_idx.append(station["name"])

    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # EXTRACT DATA FROM URLS
    print("Extracting data from list of URLs")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    #print("Scraping URLS...")
    #print(urls)


    data = []
    problem_urls = []
    with alive_bar(len(urls), force_tty=True) as bar:

        for i, url in enumerate(urls):
            search = 0
            while search >= 0:
                # Scrape site data
                # ~~~~~~~~~~~~~~~~
                search += 1
                page = requests.get(url)
                soup = BeautifulSoup(page.content, "html.parser")
                results = str(soup.find('pre'))
                sevhundy = results[results.find("700"):].split()[:11]
                eightfiddy = results[results.find("850"):].split()[:11]

                # Catch erroneous reads
                # Site can hit too many requests
                # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
                if 'e' not in sevhundy[0] and 'e' not in eightfiddy[0]:
                    search = -1
                elif search == 10:
                    print(url)
                    problem_urls.append(url)
                    search = -1

            # Extract 700 first // 850 second
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            data.append(sevhundy)
            data[-1].insert(0, dates_idx[i])
            data[-1].insert(1, station_idx[i])

            data.append(eightfiddy)
            data[-1].insert(0, dates_idx[i])
            data[-1].insert(1, station_idx[i])
            
            bar()

    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # CLEAN EXTRACTED DATA
    print("Cleaning extracted data")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # Define data cols
    # ----------------
    cols = ["Date", 
        "Station", 
        "Pressure", 
        "Height", 
        "Temp", 
        "DewPoint", 
        "Relative_Humidity", 
        "Mean_Mixed_Layer", 
        "Wind_Direction", 
        "Wind_Speed", 
        "Potential_Temp",
        "Equivalent_Potential_Temp",
        "Virtual_Potential_Temp"]

    # Remove incomplete rows from dataset
    # -----------------------------------
    data = [row for row in data if len(row) >= len(cols)]

    # Remove rogue "e" values from pressure field
    # -------------------------------------------
    pressures = [700, 850]
    ctr = 0
    for item in data:
        if(not str(item[2]).isnumeric()):
            item[2] = pressures[ctr%2]
        ctr += 1

    # Convert data to Pandas DataFrame
    # --------------------------------
    new_data = pd.DataFrame(data, columns=cols)
    return new_data

# %%
weather_data = import_weather_data()
for index, row in weather_data.iterrows():
    print("{}\n".format(row))
# Out:
# Date                         2020-01-01
# Station                      Port Hardy
# Pressure                            700
# Height                           2856.0
# Temp                               -4.3
# DewPoint                           -5.8
# Relative_Humidity                  89.0
# Mean_Mixed_Layer                   3.56
# Wind_Direction                    250.0
# Wind_Speed                       87.044
# Potential_Temp                    297.7
# Equivalent_Potential_Temp         308.6
# Virtual_Potential_Temp            298.3
# Name: 0, dtype: object
#
# Date                         2020-01-01
# Station                      Port Hardy
# Pressure                            850
# Height                           1301.0
# Temp                                3.4
# DewPoint                            1.9
# Relative_Humidity                  90.0
# Mean_Mixed_Layer                   5.19
# Wind_Direction                    250.0
# Wind_Speed                       59.264
# Potential_Temp                    289.7
# Equivalent_Potential_Temp         304.8
# Virtual_Potential_Temp            290.6
# Name: 1, dtype: object
#
# Date                         2020-01-01
# Station                      Quillayute
# Pressure                            850
# Height                           1393.0
# Temp                                6.2
# DewPoint                            6.2
# Relative_Humidity                 100.0
# Mean_Mixed_Layer                   7.04
# Wind_Direction                    260.0
# Wind_Speed                       81.488
# Potential_Temp                    292.6
# Equivalent_Potential_Temp         313.1
# Virtual_Potential_Temp            293.9
# Name: 2, dtype: object
#
# Date                         2020-01-01
# Station                          Vernon
# Pressure                            700
# Height                           2880.0
# Temp                               -5.5
# DewPoint                           -7.0
# Relative_Humidity                  89.0
# Mean_Mixed_Layer                   3.25
# Wind_Direction                    260.0
# Wind_Speed                       94.452
# Potential_Temp                    296.4
# Equivalent_Potential_Temp         306.3
# Virtual_Potential_Temp            296.9
# Name: 3, dtype: object
#
# Date                         2020-01-02
# Station                      Quillayute
# Pressure                            700
# Height                           2946.0
# Temp                              -10.7
# DewPoint                          -23.7
# Relative_Humidity                  34.0
# Mean_Mixed_Layer                   0.81
# Wind_Direction                    260.0
# Wind_Speed                       50.004
# Potential_Temp                    290.6
# Equivalent_Potential_Temp         293.2
# Virtual_Potential_Temp            290.8
# Name: 4, dtype: object
#
# Date                         2020-01-02
# Station                          Vernon
# Pressure                            700
# Height                           2882.0
# Temp                               -9.5
# DewPoint                          -12.3
# Relative_Humidity                  80.0
# Mean_Mixed_Layer                   2.14
# Wind_Direction                    305.0
# Wind_Speed                       31.484
# Potential_Temp                    291.9
# Equivalent_Potential_Temp         298.5
# Virtual_Potential_Temp            292.3
# Name: 5, dtype: object
#
# Date                         2020-01-03
# Station                      Port Hardy
# Pressure                            700
# Height                           2889.0
# Temp                               -2.9
# DewPoint                           -4.7
# Relative_Humidity                  87.0
# Mean_Mixed_Layer                   3.87
# Wind_Direction                    245.0
# Wind_Speed                         92.6
# Potential_Temp                    299.2
# Equivalent_Potential_Temp         311.1
# Virtual_Potential_Temp            299.9
# Name: 6, dtype: object
#
# Date                         2020-01-04
# Station                      Port Hardy
# Pressure                            700
# Height                           2791.0
# Temp                               -5.3
# DewPoint                           -6.9
# Relative_Humidity                  89.0
# Mean_Mixed_Layer                   3.27
# Wind_Direction                    200.0
# Wind_Speed                      124.084
# Potential_Temp                    296.6
# Equivalent_Potential_Temp         306.6
# Virtual_Potential_Temp            297.2
# Name: 7, dtype: object
#
# Date                         2020-01-04
# Station                      Quillayute
# Pressure                            700
# Height                           2942.0
# Temp                               -4.5
# DewPoint                          -20.5
# Relative_Humidity                  27.0
# Mean_Mixed_Layer                   1.08
# Wind_Direction                    215.0
# Wind_Speed                      112.972
# Potential_Temp                    297.5
# Equivalent_Potential_Temp         301.0
# Virtual_Potential_Temp            297.7
# Name: 8, dtype: object
#
# Date                         2020-01-04
# Station                      Quillayute
# Pressure                            850
# Height                           1387.0
# Temp                                5.2
# DewPoint                            5.1
# Relative_Humidity                  99.0
# Mean_Mixed_Layer                   6.52
# Wind_Direction                    210.0
# Wind_Speed                      105.564
# Potential_Temp                    291.6
# Equivalent_Potential_Temp         310.5
# Virtual_Potential_Temp            292.7
# Name: 9, dtype: object
#
# Date                         2020-01-04
# Station                          Vernon
# Pressure                            700
# Height                           2937.0
# Temp                               -5.7
# DewPoint                          -10.7
# Relative_Humidity                  68.0
# Mean_Mixed_Layer                   2.43
# Wind_Direction                    235.0
# Wind_Speed                       87.044
# Potential_Temp                    296.1
# Equivalent_Potential_Temp         303.7
# Virtual_Potential_Temp            296.6
# Name: 10, dtype: object
#
# Date                         2020-01-07
# Station                      Port Hardy
# Pressure                            700
# Height                           2958.0
# Temp                               -8.1
# DewPoint                          -13.0
# Relative_Humidity                  68.0
# Mean_Mixed_Layer                   2.02
# Wind_Direction                    265.0
# Wind_Speed                        64.82
# Potential_Temp                    293.5
# Equivalent_Potential_Temp         299.8
# Virtual_Potential_Temp            293.8
# Name: 11, dtype: object
#
# Date                         2020-01-07
# Station                      Quillayute
# Pressure                            700
# Height                           3035.0
# Temp                               -5.3
# DewPoint                           -5.5
# Relative_Humidity                  98.0
# Mean_Mixed_Layer                   3.64
# Wind_Direction                    265.0
# Wind_Speed                        64.82
# Potential_Temp                    296.6
# Equivalent_Potential_Temp         307.7
# Virtual_Potential_Temp            297.2
# Name: 12, dtype: object
#
# Date                         2020-01-07
# Station                      Quillayute
# Pressure                            850
# Height                           1486.0
# Temp                                3.0
# DewPoint                            2.9
# Relative_Humidity                  99.0
# Mean_Mixed_Layer                   5.58
# Wind_Direction                    260.0
# Wind_Speed                       51.856
# Potential_Temp                    289.3
# Equivalent_Potential_Temp         305.4
# Virtual_Potential_Temp            290.2
# Name: 13, dtype: object
#
# Date                         2020-01-07
# Station                          Vernon
# Pressure                            700
# Height                           2951.0
# Temp                               -9.9
# DewPoint                          -11.8
# Relative_Humidity                  86.0
# Mean_Mixed_Layer                   2.22
# Wind_Direction                    280.0
# Wind_Speed                         46.3
# Potential_Temp                    291.5
# Equivalent_Potential_Temp         298.3
# Virtual_Potential_Temp            291.9
# Name: 14, dtype: object
#
# Date                         2020-01-08
# Station                      Port Hardy
# Pressure                            700
# Height                           2833.0
# Temp                               -9.9
# DewPoint                          -12.1
# Relative_Humidity                  84.0
# Mean_Mixed_Layer                   2.17
# Wind_Direction                    285.0
# Wind_Speed                       44.448
# Potential_Temp                    291.5
# Equivalent_Potential_Temp         298.1
# Virtual_Potential_Temp            291.9
# Name: 15, dtype: object
#
# Date                         2020-01-08
# Station                      Quillayute
# Pressure                            700
# Height                           2894.0
# Temp                               -7.9
# DewPoint                           -8.4
# Relative_Humidity                  96.0
# Mean_Mixed_Layer                   2.91
# Wind_Direction                    210.0
# Wind_Speed                       57.412
# Potential_Temp                    293.7
# Equivalent_Potential_Temp         302.6
# Virtual_Potential_Temp            294.2
# Name: 16, dtype: object
#
# Date                         2020-01-08
# Station                          Vernon
# Pressure                            700
# Height                           2888.0
# Temp                               -8.3
# DewPoint                          -10.1
# Relative_Humidity                  87.0
# Mean_Mixed_Layer                   2.55
# Wind_Direction                    235.0
# Wind_Speed                       88.896
# Potential_Temp                    293.3
# Equivalent_Potential_Temp         301.1
# Virtual_Potential_Temp            293.7
# Name: 17, dtype: object
#
# Date                         2020-01-11
# Station                      Port Hardy
# Pressure                            700
# Height                           2787.0
# Temp                              -10.9
# DewPoint                          -12.8
# Relative_Humidity                  86.0
# Mean_Mixed_Layer                   2.05
# Wind_Direction                    190.0
# Wind_Speed                       44.448
# Potential_Temp                    290.4
# Equivalent_Potential_Temp         296.7
# Virtual_Potential_Temp            290.8
# Name: 18, dtype: object
#
# Date                         2020-01-11
# Station                      Quillayute
# Pressure                            700
# Height                           2851.0
# Temp                              -10.9
# DewPoint                          -13.8
# Relative_Humidity                  79.0
# Mean_Mixed_Layer                   1.89
# Wind_Direction                    220.0
# Wind_Speed                       68.524
# Potential_Temp                    290.4
# Equivalent_Potential_Temp         296.2
# Virtual_Potential_Temp            290.7
# Name: 19, dtype: object
#
# Date                         2020-01-11
# Station                          Vernon
# Pressure                            700
# Height                           2836.0
# Temp                              -11.3
# DewPoint                          -12.7
# Relative_Humidity                  89.0
# Mean_Mixed_Layer                   2.07
# Wind_Direction                    255.0
# Wind_Speed                         46.3
# Potential_Temp                    289.9
# Equivalent_Potential_Temp         296.3
# Virtual_Potential_Temp            290.3
# Name: 20, dtype: object
#
# Date                         2020-01-19
# Station                      Port Hardy
# Pressure                            700
# Height                           2923.0
# Temp                               -8.1
# DewPoint                           -9.8
# Relative_Humidity                  88.0
# Mean_Mixed_Layer                   2.61
# Wind_Direction                    210.0
# Wind_Speed                      105.564
# Potential_Temp                    293.5
# Equivalent_Potential_Temp         301.5
# Virtual_Potential_Temp            293.9
# Name: 21, dtype: object
#
# Date                         2020-01-19
# Station                      Quillayute
# Pressure                            700
# Height                           3014.0
# Temp                               -7.5
# DewPoint                          -14.5
# Relative_Humidity                  57.0
# Mean_Mixed_Layer                   1.78
# Wind_Direction                    225.0
# Wind_Speed                        55.56
# Potential_Temp                    294.1
# Equivalent_Potential_Temp         299.8
# Virtual_Potential_Temp            294.5
# Name: 22, dtype: object
#
# Date                         2020-01-19
# Station                          Vernon
# Pressure                            700
# Height                           3002.0
# Temp                              -10.9
# DewPoint                          -13.1
# Relative_Humidity                  84.0
# Mean_Mixed_Layer                    2.0
# Wind_Direction                    260.0
# Wind_Speed                        83.34
# Potential_Temp                    290.4
# Equivalent_Potential_Temp         296.5
# Virtual_Potential_Temp            290.7
# Name: 23, dtype: object
#
# Date                         2020-01-20
# Station                      Port Hardy
# Pressure                            700
# Height                           2952.0
# Temp                               -6.3
# DewPoint                           -8.0
# Relative_Humidity                  88.0
# Mean_Mixed_Layer                    3.0
# Wind_Direction                    200.0
# Wind_Speed                       96.304
# Potential_Temp                    295.5
# Equivalent_Potential_Temp         304.7
# Virtual_Potential_Temp            296.0
# Name: 24, dtype: object
#
# Date                         2020-01-20
# Station                      Quillayute
# Pressure                            700
# Height                           3045.0
# Temp                               -4.1
# DewPoint                           -5.1
# Relative_Humidity                  93.0
# Mean_Mixed_Layer                   3.76
# Wind_Direction                    200.0
# Wind_Speed                       66.672
# Potential_Temp                    297.9
# Equivalent_Potential_Temp         309.4
# Virtual_Potential_Temp            298.6
# Name: 25, dtype: object
#
# Date                         2020-01-20
# Station                      Quillayute
# Pressure                            850
# Height                           1483.0
# Temp                                4.2
# DewPoint                            3.6
# Relative_Humidity                  96.0
# Mean_Mixed_Layer                   5.86
# Wind_Direction                    195.0
# Wind_Speed                       66.672
# Potential_Temp                    290.5
# Equivalent_Potential_Temp         307.5
# Virtual_Potential_Temp            291.6
# Name: 26, dtype: object
#
# Date                         2020-01-20
# Station                          Vernon
# Pressure                            700
# Height                           3062.0
# Temp                               -4.9
# DewPoint                           -6.6
# Relative_Humidity                  88.0
# Mean_Mixed_Layer                   3.35
# Wind_Direction                    235.0
# Wind_Speed                       68.524
# Potential_Temp                    297.0
# Equivalent_Potential_Temp         307.3
# Virtual_Potential_Temp            297.6
# Name: 27, dtype: object
#
# Date                         2020-01-21
# Station                      Port Hardy
# Pressure                            700
# Height                           2915.0
# Temp                               -6.9
# DewPoint                          -33.9
# Relative_Humidity                  10.0
# Mean_Mixed_Layer                   0.31
# Wind_Direction                    175.0
# Wind_Speed                       59.264
# Potential_Temp                    294.8
# Equivalent_Potential_Temp         295.9
# Virtual_Potential_Temp            294.9
# Name: 28, dtype: object
#
# Date                         2020-01-21
# Station                      Quillayute
# Pressure                            700
# Height                           2948.0
# Temp                               -7.1
# DewPoint                           -9.0
# Relative_Humidity                  86.0
# Mean_Mixed_Layer                   2.78
# Wind_Direction                    180.0
# Wind_Speed                       40.744
# Potential_Temp                    294.6
# Equivalent_Potential_Temp         303.1
# Virtual_Potential_Temp            295.1
# Name: 29, dtype: object
#
# Date                         2020-01-21
# Station                          Vernon
# Pressure                            700
# Height                           2968.0
# Temp                               -7.5
# DewPoint                          -10.8
# Relative_Humidity                  77.0
# Mean_Mixed_Layer                   2.41
# Wind_Direction                    245.0
# Wind_Speed                         46.3
# Potential_Temp                    294.1
# Equivalent_Potential_Temp         301.6
# Virtual_Potential_Temp            294.6
# Name: 30, dtype: object
#
# Date                         2020-01-22
# Station                      Port Hardy
# Pressure                            700
# Height                           2788.0
# Temp                              -11.5
# DewPoint                          -14.8
# Relative_Humidity                  77.0
# Mean_Mixed_Layer                   1.74
# Wind_Direction                    200.0
# Wind_Speed                       48.152
# Potential_Temp                    289.7
# Equivalent_Potential_Temp         295.1
# Virtual_Potential_Temp            290.0
# Name: 31, dtype: object
#
# Date                         2020-01-22
# Station                      Quillayute
# Pressure                            700
# Height                           2868.0
# Temp                              -11.5
# DewPoint                          -12.6
# Relative_Humidity                  92.0
# Mean_Mixed_Layer                   2.08
# Wind_Direction                    215.0
# Wind_Speed                       68.524
# Potential_Temp                    289.7
# Equivalent_Potential_Temp         296.1
# Virtual_Potential_Temp            290.1
# Name: 32, dtype: object
#
# Date                         2020-01-22
# Station                          Vernon
# Pressure                            700
# Height                           2883.0
# Temp                              -10.3
# DewPoint                          -16.3
# Relative_Humidity                  61.0
# Mean_Mixed_Layer                   1.54
# Wind_Direction                    240.0
# Wind_Speed                       48.152
# Potential_Temp                    291.1
# Equivalent_Potential_Temp         295.9
# Virtual_Potential_Temp            291.3
# Name: 33, dtype: object
#
# Date                         2020-01-23
# Station                      Port Hardy
# Pressure                            700
# Height                           2917.0
# Temp                               -4.7
# DewPoint                           -6.6
# Relative_Humidity                  87.0
# Mean_Mixed_Layer                   3.35
# Wind_Direction                    240.0
# Wind_Speed                       61.116
# Potential_Temp                    297.2
# Equivalent_Potential_Temp         307.5
# Virtual_Potential_Temp            297.9
# Name: 34, dtype: object
#
# Date                         2020-01-23
# Station                      Quillayute
# Pressure                            700
# Height                           2985.0
# Temp                               -3.1
# DewPoint                           -3.2
# Relative_Humidity                  99.0
# Mean_Mixed_Layer                   4.34
# Wind_Direction                    255.0
# Wind_Speed                       79.636
# Potential_Temp                    299.0
# Equivalent_Potential_Temp         312.2
# Virtual_Potential_Temp            299.8
# Name: 35, dtype: object
#
# Date                         2020-01-23
# Station                      Quillayute
# Pressure                            850
# Height                           1420.0
# Temp                                3.8
# DewPoint                            3.8
# Relative_Humidity                 100.0
# Mean_Mixed_Layer                   5.95
# Wind_Direction                    245.0
# Wind_Speed                       51.856
# Potential_Temp                    290.1
# Equivalent_Potential_Temp         307.3
# Virtual_Potential_Temp            291.2
# Name: 36, dtype: object
#
# Date                         2020-01-23
# Station                          Vernon
# Pressure                            700
# Height                           2983.0
# Temp                              -11.5
# DewPoint                          -15.5
# Relative_Humidity                  72.0
# Mean_Mixed_Layer                   1.64
# Wind_Direction                    240.0
# Wind_Speed                       29.632
# Potential_Temp                    289.7
# Equivalent_Potential_Temp         294.8
# Virtual_Potential_Temp            290.0
# Name: 37, dtype: object
#
# Date                         2020-01-24
# Station                      Port Hardy
# Pressure                            700
# Height                           2918.0
# Temp                               -8.5
# DewPoint                          -12.7
# Relative_Humidity                  72.0
# Mean_Mixed_Layer                   2.07
# Wind_Direction                    195.0
# Wind_Speed                       38.892
# Potential_Temp                    293.0
# Equivalent_Potential_Temp         299.4
# Virtual_Potential_Temp            293.4
# Name: 38, dtype: object
#
# Date                         2020-01-24
# Station                      Quillayute
# Pressure                            700
# Height                           2973.0
# Temp                               -4.7
# DewPoint                           -5.1
# Relative_Humidity                  97.0
# Mean_Mixed_Layer                   3.76
# Wind_Direction                    200.0
# Wind_Speed                       70.376
# Potential_Temp                    297.2
# Equivalent_Potential_Temp         308.7
# Virtual_Potential_Temp            297.9
# Name: 39, dtype: object
#
# Date                         2020-01-24
# Station                      Quillayute
# Pressure                            850
# Height                           1417.0
# Temp                                4.6
# DewPoint                            4.4
# Relative_Humidity                  99.0
# Mean_Mixed_Layer                    6.2
# Wind_Direction                    200.0
# Wind_Speed                       48.152
# Potential_Temp                    290.9
# Equivalent_Potential_Temp         308.9
# Virtual_Potential_Temp            292.0
# Name: 40, dtype: object
#
# Date                         2020-01-24
# Station                          Vernon
# Pressure                            700
# Height                           2995.0
# Temp                               -5.5
# DewPoint                           -7.2
# Relative_Humidity                  88.0
# Mean_Mixed_Layer                    3.2
# Wind_Direction                    215.0
# Wind_Speed                       38.892
# Potential_Temp                    296.4
# Equivalent_Potential_Temp         306.1
# Virtual_Potential_Temp            296.9
# Name: 41, dtype: object
#
# Date                         2020-01-25
# Station                      Port Hardy
# Pressure                            700
# Height                           2897.0
# Temp                               -9.9
# DewPoint                          -12.7
# Relative_Humidity                  80.0
# Mean_Mixed_Layer                   2.07
# Wind_Direction                    220.0
# Wind_Speed                       35.188
# Potential_Temp                    291.5
# Equivalent_Potential_Temp         297.9
# Virtual_Potential_Temp            291.9
# Name: 42, dtype: object
#
# Date                         2020-01-25
# Station                      Quillayute
# Pressure                            700
# Height                           2963.0
# Temp                               -9.9
# DewPoint                          -19.9
# Relative_Humidity                  44.0
# Mean_Mixed_Layer                   1.13
# Wind_Direction                    245.0
# Wind_Speed                       50.004
# Potential_Temp                    291.5
# Equivalent_Potential_Temp         295.1
# Virtual_Potential_Temp            291.7
# Name: 43, dtype: object
#
# Date                         2020-01-25
# Station                          Vernon
# Pressure                            700
# Height                           2942.0
# Temp                               -9.9
# DewPoint                          -11.8
# Relative_Humidity                  86.0
# Mean_Mixed_Layer                   2.22
# Wind_Direction                    240.0
# Wind_Speed                       48.152
# Potential_Temp                    291.5
# Equivalent_Potential_Temp         298.3
# Virtual_Potential_Temp            291.9
# Name: 44, dtype: object
#
# Date                         2020-01-26
# Station                      Port Hardy
# Pressure                            700
# Height                           2944.0
# Temp                               -7.5
# DewPoint                          -33.5
# Relative_Humidity                  10.0
# Mean_Mixed_Layer                   0.33
# Wind_Direction                    205.0
# Wind_Speed                       51.856
# Potential_Temp                    294.1
# Equivalent_Potential_Temp         295.3
# Virtual_Potential_Temp            294.2
# Name: 45, dtype: object
#
# Date                         2020-01-26
# Station                      Quillayute
# Pressure                            700
# Height                           2999.0
# Temp                               -6.3
# DewPoint                          -36.3
# Relative_Humidity                   7.0
# Mean_Mixed_Layer                   0.25
# Wind_Direction                    185.0
# Wind_Speed                        7.408
# Potential_Temp                    295.5
# Equivalent_Potential_Temp         296.4
# Virtual_Potential_Temp            295.5
# Name: 46, dtype: object
#
# Date                         2020-01-26
# Station                      Quillayute
# Pressure                            850
# Height                           1454.0
# Temp                                4.0
# DewPoint                          -16.0
# Relative_Humidity                  22.0
# Mean_Mixed_Layer                    1.3
# Wind_Direction                    200.0
# Wind_Speed                       16.668
# Potential_Temp                    290.3
# Equivalent_Potential_Temp         294.4
# Virtual_Potential_Temp            290.6
# Name: 47, dtype: object
#
# Date                         2020-01-26
# Station                          Vernon
# Pressure                            700
# Height                           2979.0
# Temp                               -9.7
# DewPoint                          -12.1
# Relative_Humidity                  83.0
# Mean_Mixed_Layer                   2.17
# Wind_Direction                    305.0
# Wind_Speed                       12.964
# Potential_Temp                    291.7
# Equivalent_Potential_Temp         298.4
# Virtual_Potential_Temp            292.1
# Name: 48, dtype: object
#
# Date                         2020-01-27
# Station                      Port Hardy
# Pressure                            700
# Height                           2889.0
# Temp                              -10.5
# DewPoint                          -12.2
# Relative_Humidity                  87.0
# Mean_Mixed_Layer                   2.15
# Wind_Direction                    180.0
# Wind_Speed                       61.116
# Potential_Temp                    290.8
# Equivalent_Potential_Temp         297.4
# Virtual_Potential_Temp            291.2
# Name: 49, dtype: object
#
# Date                         2020-01-27
# Station                      Quillayute
# Pressure                            700
# Height                           2953.0
# Temp                               -9.9
# DewPoint                          -11.0
# Relative_Humidity                  92.0
# Mean_Mixed_Layer                   2.37
# Wind_Direction                    200.0
# Wind_Speed                        64.82
# Potential_Temp                    291.5
# Equivalent_Potential_Temp         298.7
# Virtual_Potential_Temp            291.9
# Name: 50, dtype: object
#
# Date                         2020-01-27
# Station                          Vernon
# Pressure                            700
# Height                           2950.0
# Temp                              -10.5
# DewPoint                          -11.8
# Relative_Humidity                  90.0
# Mean_Mixed_Layer                   2.22
# Wind_Direction                    255.0
# Wind_Speed                       38.892
# Potential_Temp                    290.8
# Equivalent_Potential_Temp         297.6
# Virtual_Potential_Temp            291.2
# Name: 51, dtype: object
#
# Date                         2020-01-28
# Station                      Port Hardy
# Pressure                            700
# Height                           2899.0
# Temp                              -10.3
# DewPoint                          -12.3
# Relative_Humidity                  85.0
# Mean_Mixed_Layer                   2.14
# Wind_Direction                    210.0
# Wind_Speed                       50.004
# Potential_Temp                    291.1
# Equivalent_Potential_Temp         297.6
# Virtual_Potential_Temp            291.4
# Name: 52, dtype: object
#
# Date                         2020-01-28
# Station                      Quillayute
# Pressure                            700
# Height                           2959.0
# Temp                               -5.5
# DewPoint                           -6.4
# Relative_Humidity                  93.0
# Mean_Mixed_Layer                    3.4
# Wind_Direction                    210.0
# Wind_Speed                       88.896
# Potential_Temp                    296.4
# Equivalent_Potential_Temp         306.7
# Virtual_Potential_Temp            297.0
# Name: 53, dtype: object
#
# Date                         2020-01-28
# Station                          Vernon
# Pressure                            700
# Height                           3004.0
# Temp                              -11.7
# DewPoint                          -29.7
# Relative_Humidity                  21.0
# Mean_Mixed_Layer                   0.47
# Wind_Direction                    265.0
# Wind_Speed                       20.372
# Potential_Temp                    289.5
# Equivalent_Potential_Temp         291.1
# Virtual_Potential_Temp            289.6
# Name: 54, dtype: object
#
# Date                         2020-01-29
# Station                      Port Hardy
# Pressure                            700
# Height                           2977.0
# Temp                               -6.3
# DewPoint                          -18.3
# Relative_Humidity                  38.0
# Mean_Mixed_Layer                    1.3
# Wind_Direction                    225.0
# Wind_Speed                       29.632
# Potential_Temp                    295.5
# Equivalent_Potential_Temp         299.7
# Virtual_Potential_Temp            295.7
# Name: 55, dtype: object
#
# Date                         2020-01-29
# Station                      Quillayute
# Pressure                            700
# Height                           3006.0
# Temp                               -7.5
# DewPoint                          -21.5
# Relative_Humidity                  32.0
# Mean_Mixed_Layer                   0.99
# Wind_Direction                    300.0
# Wind_Speed                       16.668
# Potential_Temp                    294.1
# Equivalent_Potential_Temp         297.4
# Virtual_Potential_Temp            294.3
# Name: 56, dtype: object
#
# Date                         2020-01-29
# Station                          Vernon
# Pressure                            700
# Height                           2976.0
# Temp                              -10.3
# DewPoint                          -16.3
# Relative_Humidity                  61.0
# Mean_Mixed_Layer                   1.54
# Wind_Direction                    245.0
# Wind_Speed                       24.076
# Potential_Temp                    291.1
# Equivalent_Potential_Temp         295.9
# Virtual_Potential_Temp            291.3
# Name: 57, dtype: object
#
# Date                         2020-01-30
# Station                      Quillayute
# Pressure                            700
# Height                           3020.0
# Temp                               -8.3
# DewPoint                          -37.3
# Relative_Humidity                   8.0
# Mean_Mixed_Layer                   0.22
# Wind_Direction                    275.0
# Wind_Speed                       61.116
# Potential_Temp                    293.3
# Equivalent_Potential_Temp         294.1
# Virtual_Potential_Temp            293.3
# Name: 58, dtype: object
#
# Date                         2020-01-30
# Station                          Vernon
# Pressure                            700
# Height                           2959.0
# Temp                              -10.3
# DewPoint                          -12.0
# Relative_Humidity                  87.0
# Mean_Mixed_Layer                   2.19
# Wind_Direction                    255.0
# Wind_Speed                       79.636
# Potential_Temp                    291.1
# Equivalent_Potential_Temp         297.7
# Virtual_Potential_Temp            291.4
# Name: 59, dtype: object
#
# Date                         2020-01-31
# Station                      Port Hardy
# Pressure                            700
# Height                           2931.0
# Temp                               -4.5
# DewPoint                           -6.6
# Relative_Humidity                  85.0
# Mean_Mixed_Layer                   3.35
# Wind_Direction                    235.0
# Wind_Speed                      122.232
# Potential_Temp                    297.5
# Equivalent_Potential_Temp         307.8
# Virtual_Potential_Temp            298.1
# Name: 60, dtype: object
#
# Date                         2020-01-31
# Station                          Vernon
# Pressure                            700
# Height                           3011.0
# Temp                               -8.7
# DewPoint                          -27.7
# Relative_Humidity                  20.0
# Mean_Mixed_Layer                   0.56
# Wind_Direction                    230.0
# Wind_Speed                       75.932
# Potential_Temp                    292.8
# Equivalent_Potential_Temp         294.7
# Virtual_Potential_Temp            292.9
# Name: 61, dtype: object
#
# Date                         2020-02-01
# Station                      Port Hardy
# Pressure                            700
# Height                           2892.0
# Temp                               -3.1
# DewPoint                           -4.3
# Relative_Humidity                  91.0
# Mean_Mixed_Layer                   3.99
# Wind_Direction                    230.0
# Wind_Speed                       129.64
# Potential_Temp                    299.0
# Equivalent_Potential_Temp         311.2
# Virtual_Potential_Temp            299.7
# Name: 62, dtype: object
#
# Date                         2020-02-01
# Station                      Port Hardy
# Pressure                            850
# Height                           1339.0
# Temp                                4.8
# DewPoint                            3.1
# Relative_Humidity                  89.0
# Mean_Mixed_Layer                   5.66
# Wind_Direction                    210.0
# Wind_Speed                       72.228
# Potential_Temp                    291.2
# Equivalent_Potential_Temp         307.6
# Virtual_Potential_Temp            292.2
# Name: 63, dtype: object
#
# Date                         2020-02-01
# Station                      Quillayute
# Pressure                            850
# Height                           1458.0
# Temp                                5.4
# DewPoint                            5.4
# Relative_Humidity                 100.0
# Mean_Mixed_Layer                   6.66
# Wind_Direction                    215.0
# Wind_Speed                      112.972
# Potential_Temp                    291.8
# Equivalent_Potential_Temp         311.1
# Virtual_Potential_Temp            293.0
# Name: 64, dtype: object
#
# Date                         2020-02-01
# Station                          Vernon
# Pressure                            700
# Height                           2956.0
# Temp                               -3.5
# DewPoint                           -7.2
# Relative_Humidity                  76.0
# Mean_Mixed_Layer                    3.2
# Wind_Direction                    240.0
# Wind_Speed                      137.048
# Potential_Temp                    298.6
# Equivalent_Potential_Temp         308.5
# Virtual_Potential_Temp            299.2
# Name: 65, dtype: object
#
# Date                         2020-02-01
# Station                          Vernon
# Pressure                            850
# Height                           1400.0
# Temp                                4.0
# DewPoint                            0.8
# Relative_Humidity                  80.0
# Mean_Mixed_Layer                   4.79
# Wind_Direction                    200.0
# Wind_Speed                       48.152
# Potential_Temp                    290.3
# Equivalent_Potential_Temp         304.3
# Virtual_Potential_Temp            291.2
# Name: 66, dtype: object
#
# Date                         2020-02-04
# Station                      Quillayute
# Pressure                            700
# Height                           3022.0
# Temp                               -9.7
# DewPoint                          -25.7
# Relative_Humidity                  26.0
# Mean_Mixed_Layer                   0.68
# Wind_Direction                    340.0
# Wind_Speed                       57.412
# Potential_Temp                    291.7
# Equivalent_Potential_Temp         293.9
# Virtual_Potential_Temp            291.8
# Name: 67, dtype: object
#
# Date                         2020-02-05
# Station                      Port Hardy
# Pressure                            700
# Height                           2996.0
# Temp                               -6.3
# DewPoint                           -9.1
# Relative_Humidity                  81.0
# Mean_Mixed_Layer                   2.76
# Wind_Direction                    245.0
# Wind_Speed                       31.484
# Potential_Temp                    295.5
# Equivalent_Potential_Temp         304.0
# Virtual_Potential_Temp            296.0
# Name: 68, dtype: object
#
# Date                         2020-02-05
# Station                      Quillayute
# Pressure                            700
# Height                           3042.0
# Temp                               -4.9
# DewPoint                           -5.5
# Relative_Humidity                  96.0
# Mean_Mixed_Layer                   3.64
# Wind_Direction                    285.0
# Wind_Speed                       75.932
# Potential_Temp                    297.0
# Equivalent_Potential_Temp         308.1
# Virtual_Potential_Temp            297.7
# Name: 69, dtype: object
#
# Date                         2020-02-05
# Station                          Vernon
# Pressure                            700
# Height                           2955.0
# Temp                               -9.7
# DewPoint                          -14.6
# Relative_Humidity                  67.0
# Mean_Mixed_Layer                   1.77
# Wind_Direction                    310.0
# Wind_Speed                       70.376
# Potential_Temp                    291.7
# Equivalent_Potential_Temp         297.2
# Virtual_Potential_Temp            292.0
# Name: 70, dtype: object
#
# Date                         2020-02-06
# Station                      Port Hardy
# Pressure                            700
# Height                           2985.0
# Temp                               -5.7
# DewPoint                           -8.0
# Relative_Humidity                  84.0
# Mean_Mixed_Layer                    3.0
# Wind_Direction                    280.0
# Wind_Speed                       72.228
# Potential_Temp                    296.1
# Equivalent_Potential_Temp         305.4
# Virtual_Potential_Temp            296.7
# Name: 71, dtype: object
#
# Date                         2020-02-06
# Station                      Quillayute
# Pressure                            850
# Height                           1485.0
# Temp                                3.4
# DewPoint                            3.4
# Relative_Humidity                 100.0
# Mean_Mixed_Layer                   5.78
# Wind_Direction                    280.0
# Wind_Speed                       61.116
# Potential_Temp                    289.7
# Equivalent_Potential_Temp         306.4
# Virtual_Potential_Temp            290.7
# Name: 72, dtype: object
#
# Date                         2020-02-06
# Station                          Vernon
# Pressure                            700
# Height                           2932.0
# Temp                               -7.7
# DewPoint                           -9.6
# Relative_Humidity                  86.0
# Mean_Mixed_Layer                   2.65
# Wind_Direction                    320.0
# Wind_Speed                       61.116
# Potential_Temp                    293.9
# Equivalent_Potential_Temp         302.0
# Virtual_Potential_Temp            294.4
# Name: 73, dtype: object
#
# Date                         2020-02-07
# Station                      Port Hardy
# Pressure                            700
# Height                           2972.0
# Temp                               -9.3
# DewPoint                          -13.3
# Relative_Humidity                  73.0
# Mean_Mixed_Layer                   1.97
# Wind_Direction                    310.0
# Wind_Speed                       33.336
# Potential_Temp                    292.2
# Equivalent_Potential_Temp         298.2
# Virtual_Potential_Temp            292.5
# Name: 74, dtype: object
#
# Date                         2020-02-07
# Station                      Quillayute
# Pressure                            700
# Height                           3028.0
# Temp                               -3.1
# DewPoint                           -3.2
# Relative_Humidity                  99.0
# Mean_Mixed_Layer                   4.34
# Wind_Direction                    285.0
# Wind_Speed                       101.86
# Potential_Temp                    299.0
# Equivalent_Potential_Temp         312.2
# Virtual_Potential_Temp            299.8
# Name: 75, dtype: object
#
# Date                         2020-02-07
# Station                      Quillayute
# Pressure                            850
# Height                           1466.0
# Temp                                3.8
# DewPoint                            3.7
# Relative_Humidity                  99.0
# Mean_Mixed_Layer                    5.9
# Wind_Direction                    280.0
# Wind_Speed                       77.784
# Potential_Temp                    290.1
# Equivalent_Potential_Temp         307.2
# Virtual_Potential_Temp            291.1
# Name: 76, dtype: object
#
# Date                         2020-02-08
# Station                      Quillayute
# Pressure                            700
# Height                           2939.0
# Temp                               -7.9
# DewPoint                           -8.2
# Relative_Humidity                  98.0
# Mean_Mixed_Layer                   2.96
# Wind_Direction                    230.0
# Wind_Speed                       90.748
# Potential_Temp                    293.7
# Equivalent_Potential_Temp         302.7
# Virtual_Potential_Temp            294.2
# Name: 77, dtype: object
#
# Date                         2020-02-08
# Station                          Vernon
# Pressure                            700
# Height                           2898.0
# Temp                               -8.7
# DewPoint                          -10.5
# Relative_Humidity                  87.0
# Mean_Mixed_Layer                   2.47
# Wind_Direction                    235.0
# Wind_Speed                       72.228
# Potential_Temp                    292.8
# Equivalent_Potential_Temp         300.4
# Virtual_Potential_Temp            293.3
# Name: 78, dtype: object
#
# Date                         2020-02-09
# Station                      Port Hardy
# Pressure                            700
# Height                           3071.0
# Temp                               -9.7
# DewPoint                          -39.7
# Relative_Humidity                   7.0
# Mean_Mixed_Layer                   0.17
# Wind_Direction                    345.0
# Wind_Speed                       57.412
# Potential_Temp                    291.7
# Equivalent_Potential_Temp         292.3
# Virtual_Potential_Temp            291.7
# Name: 79, dtype: object
#
# Date                         2020-02-10
# Station                      Port Hardy
# Pressure                            700
# Height                           3111.0
# Temp                               -6.9
# DewPoint                          -11.1
# Relative_Humidity                  72.0
# Mean_Mixed_Layer                   2.35
# Wind_Direction                    320.0
# Wind_Speed                       88.896
# Potential_Temp                    294.8
# Equivalent_Potential_Temp         302.1
# Virtual_Potential_Temp            295.2
# Name: 80, dtype: object
#
# Date                         2020-02-10
# Station                      Quillayute
# Pressure                            700
# Height                           3130.0
# Temp                               -3.9
# DewPoint                          -10.9
# Relative_Humidity                  58.0
# Mean_Mixed_Layer                   2.39
# Wind_Direction                    340.0
# Wind_Speed                       72.228
# Potential_Temp                    298.1
# Equivalent_Potential_Temp         305.6
# Virtual_Potential_Temp            298.6
# Name: 81, dtype: object
#
# Date                         2020-02-10
# Station                      Quillayute
# Pressure                            850
# Height                           1575.0
# Temp                                3.0
# DewPoint                          -10.0
# Relative_Humidity                  38.0
# Mean_Mixed_Layer                   2.11
# Wind_Direction                    335.0
# Wind_Speed                       51.856
# Potential_Temp                    289.3
# Equivalent_Potential_Temp         295.7
# Virtual_Potential_Temp            289.6
# Name: 82, dtype: object
#
# Date                         2020-02-11
# Station                      Port Hardy
# Pressure                            700
# Height                           3124.0
# Temp                               -4.5
# DewPoint                          -17.5
# Relative_Humidity                  36.0
# Mean_Mixed_Layer                   1.39
# Wind_Direction                    295.0
# Wind_Speed                        64.82
# Potential_Temp                    297.5
# Equivalent_Potential_Temp         302.0
# Virtual_Potential_Temp            297.7
# Name: 83, dtype: object
#
# Date                         2020-02-11
# Station                      Quillayute
# Pressure                            700
# Height                           3136.0
# Temp                               -3.3
# DewPoint                          -16.3
# Relative_Humidity                  36.0
# Mean_Mixed_Layer                   1.54
# Wind_Direction                    335.0
# Wind_Speed                       61.116
# Potential_Temp                    298.8
# Equivalent_Potential_Temp         303.8
# Virtual_Potential_Temp            299.1
# Name: 84, dtype: object
#
# Date                         2020-02-11
# Station                      Quillayute
# Pressure                            850
# Height                           1579.0
# Temp                                3.4
# DewPoint                          -10.6
# Relative_Humidity                  35.0
# Mean_Mixed_Layer                   2.02
# Wind_Direction                    340.0
# Wind_Speed                        37.04
# Potential_Temp                    289.7
# Equivalent_Potential_Temp         295.9
# Virtual_Potential_Temp            290.1
# Name: 85, dtype: object
#
# Date                         2020-02-11
# Station                          Vernon
# Pressure                            700
# Height                           3052.0
# Temp                               -8.9
# DewPoint                          -10.7
# Relative_Humidity                  87.0
# Mean_Mixed_Layer                   2.43
# Wind_Direction                    330.0
# Wind_Speed                       59.264
# Potential_Temp                    292.6
# Equivalent_Potential_Temp         300.0
# Virtual_Potential_Temp            293.0
# Name: 86, dtype: object
#
# Date                         2020-02-12
# Station                      Port Hardy
# Pressure                            700
# Height                           3056.0
# Temp                               -2.7
# DewPoint                          -28.7
# Relative_Humidity                  12.0
# Mean_Mixed_Layer                   0.51
# Wind_Direction                    320.0
# Wind_Speed                       77.784
# Potential_Temp                    299.5
# Equivalent_Potential_Temp         301.2
# Virtual_Potential_Temp            299.6
# Name: 87, dtype: object
#
# Date                         2020-02-12
# ...
# Equivalent_Potential_Temp         316.0
# Virtual_Potential_Temp            298.4
# Name: 2968, dtype: object
#
# Date                         2023-06-25
# Station                      Port Hardy
# Pressure                            850
# Height                           1539.0
# Temp                               10.2
# DewPoint                           -7.8
# Relative_Humidity                  27.0
# Mean_Mixed_Layer                   2.51
# Wind_Direction                    205.0
# Wind_Speed                       20.372
# Potential_Temp                    296.8
# Equivalent_Potential_Temp         304.6
# Virtual_Potential_Temp            297.3
# Name: 2969, dtype: object
#
# Date                         2023-06-25
# Station                      Quillayute
# Pressure                            850
# Height                           1534.0
# Temp                               10.6
# DewPoint                           -4.4
# Relative_Humidity                  35.0
# Mean_Mixed_Layer                   3.26
# Wind_Direction                    155.0
# Wind_Speed                        3.704
# Potential_Temp                    297.2
# Equivalent_Potential_Temp         307.3
# Virtual_Potential_Temp            297.8
# Name: 2970, dtype: object
#
# Date                         2023-06-26
# Station                      Port Hardy
# Pressure                            850
# Height                           1544.0
# Temp                               12.0
# DewPoint                           -9.0
# Relative_Humidity                  22.0
# Mean_Mixed_Layer                   2.29
# Wind_Direction                    350.0
# Wind_Speed                        3.704
# Potential_Temp                    298.7
# Equivalent_Potential_Temp         305.9
# Virtual_Potential_Temp            299.1
# Name: 2971, dtype: object
#
# Date                         2023-06-26
# Station                      Quillayute
# Pressure                            850
# Height                           1541.0
# Temp                               12.8
# DewPoint                           -8.2
# Relative_Humidity                  22.0
# Mean_Mixed_Layer                   2.43
# Wind_Direction                    290.0
# Wind_Speed                        3.704
# Potential_Temp                    299.5
# Equivalent_Potential_Temp         307.2
# Virtual_Potential_Temp            300.0
# Name: 2972, dtype: object
#
# Date                         2023-06-27
# Station                      Port Hardy
# Pressure                            850
# Height                           1525.0
# Temp                               13.0
# DewPoint                           -2.0
# Relative_Humidity                  35.0
# Mean_Mixed_Layer                    3.9
# Wind_Direction                    305.0
# Wind_Speed                       12.964
# Potential_Temp                    299.8
# Equivalent_Potential_Temp         311.8
# Virtual_Potential_Temp            300.5
# Name: 2973, dtype: object
#
# Date                         2023-06-28
# Station                      Port Hardy
# Pressure                            850
# Height                           1505.0
# Temp                               12.4
# DewPoint                            5.4
# Relative_Humidity                  62.0
# Mean_Mixed_Layer                   6.66
# Wind_Direction                    325.0
# Wind_Speed                       20.372
# Potential_Temp                    299.1
# Equivalent_Potential_Temp         319.1
# Virtual_Potential_Temp            300.3
# Name: 2974, dtype: object
#
# Date                         2023-06-29
# Station                      Port Hardy
# Pressure                            850
# Height                           1512.0
# Temp                               12.4
# DewPoint                            2.4
# Relative_Humidity                  50.0
# Mean_Mixed_Layer                   5.38
# Wind_Direction                    180.0
# Wind_Speed                       38.892
# Potential_Temp                    299.1
# Equivalent_Potential_Temp         315.4
# Virtual_Potential_Temp            300.1
# Name: 2975, dtype: object
#
# Date                         2023-06-30
# Station                      Port Hardy
# Pressure                            850
# Height                           1524.0
# Temp                                7.0
# DewPoint                            5.9
# Relative_Humidity                  93.0
# Mean_Mixed_Layer                   6.88
# Wind_Direction                    210.0
# Wind_Speed                       35.188
# Potential_Temp                    293.4
# Equivalent_Potential_Temp         313.5
# Virtual_Potential_Temp            294.7
# Name: 2976, dtype: object
#
# Date                         2023-06-30
# Station                      Quillayute
# Pressure                            850
# Height                           1539.0
# Temp                               11.0
# DewPoint                            4.0
# Relative_Humidity                  62.0
# Mean_Mixed_Layer                   6.03
# Wind_Direction                    215.0
# Wind_Speed                       14.816
# Potential_Temp                    297.7
# Equivalent_Potential_Temp         315.7
# Virtual_Potential_Temp            298.7
# Name: 2977, dtype: object
#
# Date                         2023-07-01
# Station                      Port Hardy
# Pressure                            850
# Height                           1524.0
# Temp                                6.6
# DewPoint                           -2.4
# Relative_Humidity                  53.0
# Mean_Mixed_Layer                    3.8
# Wind_Direction                    205.0
# Wind_Speed                       25.928
# Potential_Temp                    293.0
# Equivalent_Potential_Temp         304.4
# Virtual_Potential_Temp            293.7
# Name: 2978, dtype: object
#
# Date                         2023-07-01
# Station                      Quillayute
# Pressure                            850
# Height                           1544.0
# Temp                               10.2
# DewPoint                           -9.8
# Relative_Humidity                  23.0
# Mean_Mixed_Layer                   2.15
# Wind_Direction                    275.0
# Wind_Speed                       12.964
# Potential_Temp                    296.8
# Equivalent_Potential_Temp         303.6
# Virtual_Potential_Temp            297.2
# Name: 2979, dtype: object
#
# Date                         2023-07-02
# Station                      Quillayute
# Pressure                            850
# Height                           1566.0
# Temp                                6.8
# DewPoint                            3.8
# Relative_Humidity                  81.0
# Mean_Mixed_Layer                   5.95
# Wind_Direction                    285.0
# Wind_Speed                        18.52
# Potential_Temp                    293.3
# Equivalent_Potential_Temp         310.7
# Virtual_Potential_Temp            294.3
# Name: 2980, dtype: object
#
# Date                         2023-07-03
# Station                      Port Hardy
# Pressure                            850
# Height                           1562.0
# Temp                                8.4
# DewPoint                          -10.6
# Relative_Humidity                  25.0
# Mean_Mixed_Layer                   2.02
# Wind_Direction                    345.0
# Wind_Speed                       20.372
# Potential_Temp                    294.9
# Equivalent_Potential_Temp         301.2
# Virtual_Potential_Temp            295.3
# Name: 2981, dtype: object
#
# Date                         2023-07-03
# Station                      Quillayute
# Pressure                            850
# Height                           1547.0
# Temp                               12.2
# DewPoint                          -26.8
# Relative_Humidity                   5.0
# Mean_Mixed_Layer                   0.51
# Wind_Direction                    335.0
# Wind_Speed                       14.816
# Potential_Temp                    298.9
# Equivalent_Potential_Temp         300.7
# Virtual_Potential_Temp            299.0
# Name: 2982, dtype: object
#
# Date                         2023-07-03
# Station                          Vernon
# Pressure                            850
# Height                           1544.0
# Temp                               12.8
# DewPoint                           -3.2
# Relative_Humidity                  33.0
# Mean_Mixed_Layer                   3.57
# Wind_Direction                    305.0
# Wind_Speed                         9.26
# Potential_Temp                    299.5
# Equivalent_Potential_Temp         310.6
# Virtual_Potential_Temp            300.2
# Name: 2983, dtype: object
#
# Date                         2023-07-09
# Station                      Quillayute
# Pressure                            850
# Height                           1490.0
# Temp                               13.2
# DewPoint                           -4.8
# Relative_Humidity                  28.0
# Mean_Mixed_Layer                   3.16
# Wind_Direction                    160.0
# Wind_Speed                       16.668
# Potential_Temp                    300.0
# Equivalent_Potential_Temp         309.8
# Virtual_Potential_Temp            300.5
# Name: 2984, dtype: object
#
# Date                         2023-07-11
# Station                      Port Hardy
# Pressure                            850
# Height                           1517.0
# Temp                               11.6
# DewPoint                           -4.4
# Relative_Humidity                  32.0
# Mean_Mixed_Layer                   3.26
# Wind_Direction                    250.0
# Wind_Speed                       16.668
# Potential_Temp                    298.3
# Equivalent_Potential_Temp         308.4
# Virtual_Potential_Temp            298.9
# Name: 2985, dtype: object
#
# Date                         2023-07-11
# Station                      Quillayute
# Pressure                            850
# Height                           1516.0
# Temp                               12.0
# DewPoint                          -11.0
# Relative_Humidity                  19.0
# Mean_Mixed_Layer                   1.95
# Wind_Direction                    240.0
# Wind_Speed                        7.408
# Potential_Temp                    298.7
# Equivalent_Potential_Temp         304.9
# Virtual_Potential_Temp            299.1
# Name: 2986, dtype: object
#
# Date                         2023-07-12
# Station                      Quillayute
# Pressure                            850
# Height                           1532.0
# Temp                               12.2
# DewPoint                            0.2
# Relative_Humidity                  44.0
# Mean_Mixed_Layer                   4.59
# Wind_Direction                    240.0
# Wind_Speed                        3.704
# Potential_Temp                    298.9
# Equivalent_Potential_Temp         312.9
# Virtual_Potential_Temp            299.7
# Name: 2987, dtype: object
#
# Date                         2023-07-13
# Station                      Port Hardy
# Pressure                            850
# Height                           1522.0
# Temp                               10.6
# DewPoint                            8.1
# Relative_Humidity                  85.0
# Mean_Mixed_Layer                   8.03
# Wind_Direction                    155.0
# Wind_Speed                       14.816
# Potential_Temp                    297.2
# Equivalent_Potential_Temp         320.9
# Virtual_Potential_Temp            298.7
# Name: 2988, dtype: object
#
# Date                         2023-07-13
# Station                      Quillayute
# Pressure                            850
# Height                           1527.0
# Temp                               10.0
# DewPoint                            4.0
# Relative_Humidity                  66.0
# Mean_Mixed_Layer                   6.03
# Wind_Direction                    195.0
# Wind_Speed                        1.852
# Potential_Temp                    296.6
# Equivalent_Potential_Temp         314.5
# Virtual_Potential_Temp            297.7
# Name: 2989, dtype: object
#
# Date                         2023-07-14
# Station                      Port Hardy
# Pressure                            850
# Height                           1550.0
# Temp                               11.2
# DewPoint                            5.2
# Relative_Humidity                  67.0
# Mean_Mixed_Layer                   6.56
# Wind_Direction                    170.0
# Wind_Speed                       29.632
# Potential_Temp                    297.9
# Equivalent_Potential_Temp         317.4
# Virtual_Potential_Temp            299.1
# Name: 2990, dtype: object
#
# Date                         2023-07-15
# Station                      Port Hardy
# Pressure                            850
# Height                           1566.0
# Temp                               12.2
# DewPoint                            4.2
# Relative_Humidity                  58.0
# Mean_Mixed_Layer                   6.12
# Wind_Direction                    215.0
# Wind_Speed                        18.52
# Potential_Temp                    298.9
# Equivalent_Potential_Temp         317.3
# Virtual_Potential_Temp            300.0
# Name: 2991, dtype: object
#
# Date                         2023-07-16
# Station                      Port Hardy
# Pressure                            850
# Height                           1539.0
# Temp                               11.6
# DewPoint                            7.4
# Relative_Humidity                  75.0
# Mean_Mixed_Layer                   7.65
# Wind_Direction                    170.0
# Wind_Speed                        27.78
# Potential_Temp                    298.3
# Equivalent_Potential_Temp         321.0
# Virtual_Potential_Temp            299.7
# Name: 2992, dtype: object
#
# Date                         2023-07-18
# Station                      Port Hardy
# Pressure                            850
# Height                           1532.0
# Temp                                6.4
# DewPoint                            4.8
# Relative_Humidity                  90.0
# Mean_Mixed_Layer                   6.38
# Wind_Direction                    235.0
# Wind_Speed                        18.52
# Potential_Temp                    292.8
# Equivalent_Potential_Temp         311.5
# Virtual_Potential_Temp            294.0
# Name: 2993, dtype: object
#
# Date                         2023-07-19
# Station                      Port Hardy
# Pressure                            850
# Height                           1560.0
# Temp                                9.8
# DewPoint                            2.8
# Relative_Humidity                  62.0
# Mean_Mixed_Layer                   5.54
# Wind_Direction                    190.0
# Wind_Speed                        7.408
# Potential_Temp                    296.4
# Equivalent_Potential_Temp         312.9
# Virtual_Potential_Temp            297.4
# Name: 2994, dtype: object
#
# Date                         2023-08-24
# Station                      Port Hardy
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 2995, dtype: object
#
# Date                         2023-08-25
# Station                      Port Hardy
# Pressure                            850
# Height                           1540.0
# Temp                               12.2
# DewPoint                            3.2
# Relative_Humidity                  54.0
# Mean_Mixed_Layer                    5.7
# Wind_Direction                    115.0
# Wind_Speed                       20.372
# Potential_Temp                    298.9
# Equivalent_Potential_Temp         316.1
# Virtual_Potential_Temp            299.9
# Name: 2996, dtype: object
#
# Date                         2023-08-25
# Station                          Vernon
# Pressure                            850
# Height                           1567.0
# Temp                               11.4
# DewPoint                            4.4
# Relative_Humidity                  62.0
# Mean_Mixed_Layer                    6.2
# Wind_Direction                     90.0
# Wind_Speed                        5.556
# Potential_Temp                    298.1
# Equivalent_Potential_Temp         316.6
# Virtual_Potential_Temp            299.2
# Name: 2997, dtype: object

# %%
def find_missing_vals(weather_data):
    missing_data = []
    stations = [
        {"id": 72797, "name": "Quillayute"},
        {"id": 73033, "name": "Vernon"},
        {"id": 71109, "name": "Port Hardy"}]
    pressures = [700, 850]
    start_date = date(2020, 1, 1)
    end_date = datetime.today().date()
    dates = daterange(start_date, end_date)
    
    # Loop through all dates from Jan 1st 2020 until today
    # For each date in the range, find the station / pressure combinations that are missing
    for i, d in enumerate(dates):
        missing_data.append({
            'date': str(d),
            'stations': []
        })
        for j, s in enumerate(stations):
            # Create empty array of pressures for each station at this date value
            missing_data[i]['stations'].append({'id': s['id'], 'name': s['name'], 'pressures': []}) 
            for p in pressures:
                x = weather_data.loc[(weather_data['Date'] == str(d)) & (weather_data['Station'] == str(s['name'])) & (weather_data['Pressure'] == int(p))]

                # If there is no record in the dataset for this date...
                if x.empty:
                    missing_data[i]['stations'][j]['pressures'].append(str(p))
                    #missing_data[i][s['id']]['pressures'].append(str(p))
                    '''
                    missing_data.append({
                        "Date": str(d),
                        "Station": s,
                        "Pressure": p})
                    '''

                    break

                # If there are null values for Temp or WindSpeed...
                if x['Temp'].empty or x['Wind_Speed'].empty:
                    missing_data[i]['stations'][j]['pressures'].append(str(p))
                    #missing_data[i][s['id']]['pressures'].append(str(p))
                    '''
                    missing_data.append({
                        "Date": str(d),
                        "Station": s,
                        "Pressure": p})
                    break
                    '''
                    
    return missing_data

# %%
missing_data = find_missing_vals(weather_data)
print(len(missing_data))
# Out:
# 1385

# %%
for row in missing_data:
    print(row)
    print("\n")
# Out:
# {'date': '2020-01-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-01-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-01-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-01-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-01-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-01-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-01-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-01-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-01-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-01-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-01-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-01-17', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-01-18', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-01-19', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-01-31', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-02-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-02-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-02-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-02-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-02-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-02-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-02-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-02-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-02-17', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-02-18', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-02-19', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-02-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-02-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-17', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-18', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-03-19', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-03-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-03-31', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-04-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-04-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-04-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-04-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-04-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-04-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-04-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-04-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-04-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-04-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-04-17', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-04-18', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-04-19', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-04-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-04-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-04-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-05-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-05-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-05-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-05-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-05-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-05-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-05-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-05-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-05-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-05-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-05-17', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-05-18', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-05-19', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-05-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-05-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-05-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-05-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-05-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-05-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-05-31', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-06-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-06-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-06-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-06-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-06-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-06-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-06-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-17', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-06-18', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-06-19', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-06-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-06-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-06-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-06-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-06-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-06-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-06-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-06-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-06-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-06-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-06-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-07-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-07-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-07-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-07-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-07-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-07-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-07-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-07-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-17', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-18', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-19', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-07-31', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-08-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-08-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-08-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-08-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-08-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-08-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-08-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': []}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-08-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-08-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-08-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-08-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-08-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]}
#
#
# {'date': '2020-08-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': []}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-08-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-08-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2020-08-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# ...
#
#
# {'date': '2023-08-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-17', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-18', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-19', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-08-31', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-17', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-18', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-19', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-09-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}
#
#
# {'date': '2023-10-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}]}

# %%
'''
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# CREATING RANGE OF DATES TO BE SCRAPED
print("Creating range of dates to be scraped...\n")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# Create Date Range
# -----------------
delta = timedelta(days=1)
start_date = date(2020, 1, 1)
end_date = datetime.today().date()
new_dates = daterange(start_date, end_date)


# Remove dates from list that are alrady populated in weather_data
# ----------------------------------------------------------------
for d in weather_data['Date'].unique().tolist():
    if d in new_dates:
        new_dates.remove(d)
        
incomplete_dates = weather_data[weather_data['Temp'].isna()]['Date']

dates = list(new_dates) + incomplete_dates.to_list()

print("Incomplete dates: {}\n".format(incomplete_dates))
print("Dates: {}\n".format(dates))
'''
# Out:
# '\n# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n# CREATING RANGE OF DATES TO BE SCRAPED\nprint("Creating range of dates to be scraped...\n")\n# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n\n# Create Date Range\n# -----------------\ndelta = timedelta(days=1)\nstart_date = date(2020, 1, 1)\nend_date = datetime.today().date()\nnew_dates = daterange(start_date, end_date)\n\n\n# Remove dates from list that are alrady populated in weather_data\n# ----------------------------------------------------------------\nfor d in weather_data[\'Date\'].unique().tolist():\n    if d in new_dates:\n        new_dates.remove(d)\n        \nincomplete_dates = weather_data[weather_data[\'Temp\'].isna()][\'Date\']\n\ndates = list(new_dates) + incomplete_dates.to_list()\n\nprint("Incomplete dates: {}\n".format(incomplete_dates))\nprint("Dates: {}\n".format(dates))\n'

# %%
# Scrape weather balloons for new data within defined date range
# --------------------------------------------------------------
#new_data = scrape_data(dates)
new_data = scrape_data_2(missing_data)

# Convert DataFrame to numeric values
# -----------------------------------
for col in cols[2:]:
    try:
        new_data[col] = pd.to_numeric(new_data[col])
    except Exception as e:
        print("{}: {}".format(col, e))

# Convert wind speed from Knots to KM/H
# -------------------------------------
new_data['Wind_Speed'] = new_data['Wind_Speed'].multiply(1.852)
'''
print("NEW DATA ({})".format(new_data.shape[0]))
for index, row in new_data.iterrows():
    print("{}\n".format(row))
'''

    
# Combine New and Old Data
# ------------------------
complete_data = pd.concat([weather_data, new_data])
#complete_data = complete_data.sort_values(by=['Date'])
print("COMPLETE DATA ({})".format(complete_data.shape[0]))


# Remove values that are exceptionally high or low
# ------------------------------------------------
for col in cols[2:]:
    q_low = complete_data[col].quantile(0.01)
    q_hi = complete_data[col].quantile(0.99)

    complete_clean_data = complete_data[(complete_data[col] < q_hi) & (complete_data[col] > q_low)]

final_data = patch_dataset(complete_clean_data, start_date, end_date)
print("FINAL DATA ({})".format(final_data.shape[0]))
# Out:
# Creating list of URLs to be scraped
# Creating dates list...
# Extracting data from list of URLs
# on 413: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=05&FROM=1700&TO=1723&STNM=71109&REPLOT=1
# on 829: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=10&FROM=0300&TO=0323&STNM=73033&REPLOT=1
# on 832: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=10&FROM=0400&TO=0423&STNM=73033&REPLOT=1
# on 835: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=10&FROM=0500&TO=0523&STNM=73033&REPLOT=1
# on 843: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=10&FROM=0800&TO=0823&STNM=72797&REPLOT=1
# on 846: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=10&FROM=0900&TO=0923&STNM=72797&REPLOT=1
# on 994: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=11&FROM=2700&TO=2723&STNM=73033&REPLOT=1
# on 1359: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2021&MONTH=03&FROM=2900&TO=2923&STNM=72797&REPLOT=1
# on 1662: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2021&MONTH=07&FROM=0800&TO=0823&STNM=72797&REPLOT=1
# on 1665: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2021&MONTH=07&FROM=0900&TO=0923&STNM=72797&REPLOT=1
# on 2212: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2022&MONTH=01&FROM=0700&TO=0723&STNM=73033&REPLOT=1
# on 2213: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2022&MONTH=01&FROM=0700&TO=0723&STNM=71109&REPLOT=1
# on 2325: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2022&MONTH=02&FROM=1400&TO=1423&STNM=72797&REPLOT=1
# |███████████████████████████▊            | █▆▄ 2889/4155 [70%] in 3:07:01 (~1:21:57, 0.3/s)

# %%
# Upload clean data to bucket
# ---------------------------
upload_weather_data(final_data)

# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# COMPLETE
print("Successfully completed scrape")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
complete_clean_data.head(10)
# Out:
#          Date     Station  Pressure  Height  Temp  DewPoint  \
# 0  2020-01-01  Port Hardy       700  2856.0  -4.3      -5.8
# 1  2020-01-01  Port Hardy       850  1301.0   3.4       1.9
# 2  2020-01-01  Quillayute       700  2969.0  -0.9      -0.9
# 3  2020-01-01  Quillayute       850  1393.0   6.2       6.2
# 4  2020-01-01      Vernon       700  2880.0  -5.5      -7.0
# 5  2020-01-02  Quillayute       700  2946.0 -10.7     -23.7
# 6  2020-01-02      Vernon       700  2882.0  -9.5     -12.3
# 7  2020-01-02      Vernon       850  1351.0   2.2      -4.8
# 8  2020-01-03  Port Hardy       700  2889.0  -2.9      -4.7
# 9  2020-01-03  Quillayute       700  2974.0  -2.3      -2.7
#
#    Relative_Humidity  Mean_Mixed_Layer  Wind_Direction  Wind_Speed  \
# 0               89.0              3.56           250.0      87.044
# 1               90.0              5.19           250.0      59.264
# 2              100.0              5.14           255.0     100.008
# 3              100.0              7.04           260.0      81.488
# 4               89.0              3.25           260.0      94.452
# 5               34.0              0.81           260.0      50.004
# 6               80.0              2.14           305.0      31.484
# 7               60.0              3.16           245.0      33.336
# 8               87.0              3.87           245.0      92.600
# 9               97.0              4.50           270.0      90.748
#
#    Potential_Temp  Equivalent_Potential_Temp  Virtual_Potential_Temp
# 0           297.7                      308.6                   298.3
# 1           289.7                      304.8                   290.6
# 2           301.5                      317.2                   302.4
# 3           292.6                      313.1                   293.9
# 4           296.4                      306.3                   296.9
# 5           290.6                      293.2                   290.8
# 6           291.9                      298.5                   292.3
# 7           288.4                      297.8                   289.0
# 8           299.2                      311.1                   299.9
# 9           299.9                      313.6                   300.7

# %%
final_data.tail(10)

# %%
weather_data = import_weather_data()

# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# CREATING RANGE OF DATES TO BE SCRAPED
print("Creating range of dates to be scraped")
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# Create Date Range
# -----------------
delta = timedelta(days=1)
start_date = date(2020, 1, 1)
end_date = datetime.today().date()
dates = daterange(start_date, end_date)
# Out:
# Creating range of dates to be scraped

# %%
print(weather_data['Date'])
# Out:
# 0       2020-01-01
# 1       2020-01-01
# 2       2020-01-01
# 3       2020-01-01
# 4       2020-01-01
#            ...
# 8227    2023-10-03
# 8228    2023-10-03
# 8229    2023-10-03
# 8230    2023-10-03
# 8231    2023-10-03
# Name: Date, Length: 8232, dtype: object

# %%
#incomplete_data = weather_data['Temp'].isnull()
incomplete_dates = weather_data[weather_data['Temp'].isna()]['Date']
print(incomplete_dates)
# Out:
# 5       2020-01-01
# 6       2020-01-02
# 7       2020-01-02
# 9       2020-01-02
# 13      2020-01-03
#            ...
# 8227    2023-10-03
# 8228    2023-10-03
# 8229    2023-10-03
# 8230    2023-10-03
# 8231    2023-10-03
# Name: Date, Length: 3893, dtype: object

# %%
for index, row in incomplete_data.iterrows():
    print("{}\n".format(row))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[290], line 1
# ----> 1 for index, row in incomplete_data.iterrows():
#       2     print("{}\n".format(row))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'iterrows'

# %%
incomplete_dates.head(100)
# Out:
#      Date  Station  Pressure  Height   Temp  DewPoint  Relative_Humidity  \
# 0   False    False     False   False  False     False              False
# 1   False    False     False   False  False     False              False
# 2   False    False     False   False  False     False              False
# 3   False    False     False   False  False     False              False
# 4   False    False     False   False  False     False              False
# ..    ...      ...       ...     ...    ...       ...                ...
# 95  False    False     False   False  False     False              False
# 96  False    False     False   False  False     False              False
# 97  False    False     False   False  False     False              False
# 98  False    False     False   False  False     False              False
# 99  False    False     False   False  False     False              False
#
#     Mean_Mixed_Layer  Wind_Direction  Wind_Speed  Potential_Temp  \
# 0              False           False       False           False
# 1              False           False       False           False
# 2              False           False       False           False
# 3              False           False       False           False
# 4              False           False       False           False
# ..               ...             ...         ...             ...
# 95             False           False       False           False
# 96             False           False       False           False
# 97             False           False       False           False
# 98             False           False       False           False
# 99             False           False       False           False
#
#     Equivalent_Potential_Temp  Virtual_Potential_Temp
# 0                       False                   False
# 1                       False                   False
# 2                       False                   False
# 3                       False                   False
# 4                       False                   False
# ..                        ...                     ...
# 95                      False                   False
# 96                      False                   False
# 97                      False                   False
# 98                      False                   False
# 99                      False                   False
#
# [100 rows x 13 columns]

# %%
# Remove dates from list that are alrady populated in weather_data
# ----------------------------------------------------------------
for d in weather_data['Date'].unique().tolist():
    if d in dates:
        dates.remove(d)
