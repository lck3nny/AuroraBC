# %% [markdown]
# # Scraper 3.1
# ---
# Goal of 3.1 is to include both AM and PM reading from ballon data
# - Import Dataset from GoogleCloudStorage
# - Find Missing Values in Dataset
# - Get New Data from Missing Values
# - Standardize DataTypes within New Data
# - Combine New Data with Old Data
# - Patch Missing Values within Complete Dataset
# - Upload Complete dataset to GoogleCloudStorage

# %%
import base64
import os, io
import requests
import pandas as pd
from datetime import date, datetime, timedelta
from bs4 import BeautifulSoup
import numpy as np
from math import floor
from pathlib import Path  
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
import seaborn as sns
from windrose import WindroseAxes
from PIL import Image
from google.cloud import storage
import google.cloud.logging
import logging
from flask import Response

# %%
from alive_progress import alive_bar

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '../service_account.json'

# %%
# -------------------------------------------------------------------------------
# LOGGING SETUP
# -------------------------------------------------------------------------------
client = google.cloud.logging.Client()
client.setup_logging()

# %%
# -------------------------------------------------------------------------------
# CREATE DATERANGE
# -------------------------------------------------------------------------------
def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

# %% [markdown]
# # Import Dataset
# ---
# Import existing weather data from GoogleCloudStorage as Pandas Dataframe

# %%
# -------------------------------------------------------------------------------
# IMPORT DATASET
# Function to import all weather data
# Data Patching completed in this step
# -------------------------------------------------------------------------------
def import_weather_data():
    # Connect to Google Cloud Storage
    # -------------------------------
    storage_client = storage.Client()

    # Open Bucket
    # -----------
    bucket_name = 'weather_aurorabc'
    bucket = storage_client.bucket(bucket_name)

    # Open Blob
    # ---------
    blob_name = 'weather_ampm.csv'
    #blob_name = 'backups/weather-2023-09-26.csv'
    blob = bucket.blob(blob_name)

    # Read Weather Data from Blob
    # ---------------------------
    with blob.open("r") as f:
        weather_data = pd.read_csv(f)

    # Cast all data variables to float
    weather_data = weather_data.astype(
        {'Height':'float',
        'Temp':'float',
        'DewPoint':'float',
        'Relative_Humidity':'float',
        'Mean_Mixed_Layer':'float',
        'Wind_Direction':'float',
        'Wind_Speed':'float',
        'Potential_Temp':'float',
        'Equivalent_Potential_Temp':'float',
        'Virtual_Potential_Temp':'float',
        })

    return weather_data

# %% [markdown]
# # Find Missing Values
# ---
# Look through existing dataset and create list of missing data values

# %%
# -------------------------------------------------------------------------------
# FIND MISSING VALS
# Function to find incomplete or missing vals within a dataset
# -------------------------------------------------------------------------------
def find_missing_vals(weather_data):
    missing_data = []
    stations = [
        {"id": 72797, "name": "Quillayute"},
        {"id": 73033, "name": "Vernon"},
        {"id": 71109, "name": "Port Hardy"}]
    pressures = [700, 850]
    start_date = date(2020, 1, 1)
    end_date = datetime.today().date()
    dates = daterange(start_date, end_date)
    
    # Loop through all dates from Jan 1st 2020 until today
    # For each date in the range, find the station / pressure / time combinations that are missing
    for i, d in enumerate(dates):
        missing_data.append({
            'date': str(d),
            'stations': []
        })
        for j, s in enumerate(stations):
            # Create empty array of pressures for each station at this date value
            for p in pressures:
                am = weather_data.loc[(weather_data['Date'] == str(d)) & (weather_data['Station'] == str(s['name'])) & (weather_data['Pressure'] == int(p)) & (weather_data['Time'] == 'AM')]
                pm = weather_data.loc[(weather_data['Date'] == str(d)) & (weather_data['Station'] == str(s['name'])) & (weather_data['Pressure'] == int(p)) & (weather_data['Time'] == 'PM')]
                
                
                # If there is no record in the dataset for this date...
                if am.empty or pm.empty:
                    missing_data[i]['stations'].append({'id': s['id'], 'name': s['name'], 'pressures': []}) 
                    missing_data[i]['stations'][-1]['pressures'].append(str(p))
       

                    continue
                
                # If there are null values for Temp or WindSpeed...
                if not am['Temp'].any() or not am['Wind_Speed'].any() or not pm['Temp'].any() or not pm['Wind_Speed'].any():
                    missing_data[i]['stations'].append({'id': s['id'], 'name': s['name'], 'pressures': []}) 
                    missing_data[i]['stations'][-1]['pressures'].append(str(p))
      
    
    
    # Remove unecessary rows where no new data is required
    missing_data = [x for x in missing_data if x['stations']]

    return missing_data

# %% [markdown]
# # Scrape Data
# ---
# Using a list of incomplete data, generate a list of URLs and scrape.
#
# Return new Dataset in the format of a Pandas Dataframe

# %%
def scrape_data(missing_vals):
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # GENERATE LIST OF URLS TO BE SCRAPED
    print("Creating list of URLs to be scraped")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    base_url = "http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST"
    times = {'AM': [0, 11], 'PM': [12, 23]}
    
    '''
    x = {
        'date': '2020-01-01', 
        'stations': [
            {'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, 
            {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, 
            {'id': 71109, 'name': 'Port Hardy', 'pressures': []}]
        }
    '''
    
    print("Creating dates list...")

    # Create list of URLs for each station
    # ------------------------------------
    urls = []
    dates_idx = []
    station_idx = []
    for val in missing_vals:
        d = val['date'].split('-')
        for station in val['stations']:
            for t, time in times.items():
                url = base_url
                url += "&YEAR={}".format(d[0])
                url += "&MONTH={}".format(d[1])
                url += "&FROM={:0>2d}{:0>2d}".format(int(d[2]), time[0])
                url += "&TO={:0>2d}{:0>2d}".format(int(d[2]), time[1])
                url += "&STNM={}".format(station["id"])
                url += "&REPLOT=1"
                urls.append(url)

                dates_idx.append("%02d-%02d-%02d" % (int(d[0]), int(d[1]), int(d[2])))
                station_idx.append(station["name"])

    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # EXTRACT DATA FROM URLS
    print("Extracting data from list of URLs")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    #print("Scraping URLS...")
    #print(urls)


    data = []
    ampm = 0
    problem_urls = []
    with alive_bar(len(urls), force_tty=True) as bar:
        for i, url in enumerate(urls):
            search = 0
            while search >= 0:
                # Scrape site data
                # ~~~~~~~~~~~~~~~~
                search += 1
                page = requests.get(url)
                soup = BeautifulSoup(page.content, "html.parser")
                results = str(soup.find('pre'))
                sevhundy = results[results.find("700"):].split()[:11]
                eightfiddy = results[results.find("850"):].split()[:11]

                # Catch erroneous reads
                # Site can hit too many requests
                # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
                if 'e' not in sevhundy[0] and 'e' not in eightfiddy[0]:
                    search = -1
                # Try 3 times then move on
                elif search == 3:
                    print("Could not extract data from: {}".format(url))
                    problem_urls.append(url)
                    search = -1

            # Extract 700 first // 850 second
            # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            data.append(sevhundy)
            data[-1].insert(0, dates_idx[i])
            data[-1].insert(1, station_idx[i])
            data[-1].insert(2, list(times.keys())[ampm%2])

            data.append(eightfiddy)
            data[-1].insert(0, dates_idx[i])
            data[-1].insert(1, station_idx[i])
            data[-1].insert(2, list(times.keys())[ampm%2])
            
            ampm += 1
                        
            bar()

    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # CLEAN EXTRACTED DATA
    print("Cleaning extracted data")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

    # Define data cols
    # ----------------
    cols = [
        "Date", 
        "Station", 
        "Time",
        "Pressure", 
        "Height", 
        "Temp", 
        "DewPoint", 
        "Relative_Humidity", 
        "Mean_Mixed_Layer", 
        "Wind_Direction", 
        "Wind_Speed", 
        "Potential_Temp",
        "Equivalent_Potential_Temp",
        "Virtual_Potential_Temp"]

    # Remove incomplete rows from dataset
    # -----------------------------------
    data = [row for row in data if len(row) >= len(cols)]

    # Remove rogue "e" values from pressure field
    # -------------------------------------------
    pressures = [700, 850]
    ctr = 0
    for item in data:
        if(not str(item[3]).isnumeric()):
            item[3] = pressures[ctr%2]
        ctr += 1

    # Convert data to Pandas DataFrame
    # --------------------------------
    new_data = pd.DataFrame(data, columns=cols)
    return new_data

# %% [markdown]
# # Standardize Datatypes
# ---

# %%
def standardize_dtypes(data):
    return data.astype( dtype={
                'Date' : str, 
                'Station': str,
                'Time': str,
                'Pressure': int,
                'Height': float,
                'Temp': float,
                'DewPoint': float,
                'Relative_Humidity': float,
                'Mean_Mixed_Layer': float,
                'Wind_Direction': float,
                'Wind_Speed': float,
                'Potential_Temp': float,
                'Equivalent_Potential_Temp': float,
                'Virtual_Potential_Temp': float,
                                      })

# %% [markdown]
# # Patch Dataset
# ---
# Populate missing or incomplete data entries with NaN values

# %%
# -------------------------------------------------------------------------------
# PATCH DATASET
# Function to create empty entries for missing data
# This results in a data entries for each expected date/location/pressure reading
# -------------------------------------------------------------------------------
def patch_dataset(data, start_date=date(2020, 1, 1), end_date=datetime.today().date()):

    dates = daterange(start_date, end_date)


    stations = ['Quillayute', 'Vernon', 'Port Hardy']
    times = {'AM': [0, 11], 'PM': [12, 23]}
    pressures = [700, 850]
    idx = len(data)
    # Itterate through date range
    for date in dates:
        for station in stations:
            for t, time in times.items():
                for pressure in pressures:
                    # If data is missing, add empty values
                    if data[(data['Date'] == date.strftime("%Y-%m-%d")) & (data['Station'] == station) & (data['Time'] == t) & (data['Pressure'] == pressure)].empty:
                        #print("Missing data for {}:\n\tDate:{}\n\tPressure:{}\n".format(station, date.strftime("%Y-%m-%d"), pressure))
                        new_row = {
                            'Date': date.strftime("%Y-%m-%d"), 
                            'Station': station, 
                            'Time': t,
                            'Pressure': pressure, 
                            'Height': np.nan,
                            'Temp': np.nan,
                            'DewPoint': np.nan,
                            'Relative_Humidity': np.nan,
                            'Mean_Mixed_Layer': np.nan,
                            'Wind_Direction': np.nan,
                            'Wind_Speed': np.nan,
                            'Potential_Temp': np.nan,
                            'Equivalent_Potential_Temp': np.nan,
                            'Virtual_Potential_Temp': np.nan}

                        #data.loc[idx] = new_row
                        data.loc[idx] = [date.strftime("%Y-%m-%d"), station, t, pressure, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan]
                        idx += 1
                        #data.loc[-1] = new_row

    # Return complete data
    print("Patching Complete")
    return data.sort_values(by=['Date', 'Station', 'Pressure'])

# %% [markdown]
# # Upload Complete Dataset
# ---
# Upload a complete dataset to the GoogleCloudStorage bucket and create daily backup

# %%
# -------------------------------------------------------------------------------
# UPLOAD WEATHER DATA
# Saves data to cloud bucket
# -------------------------------------------------------------------------------
def upload_weather_data(data):
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
    # SAVE DATA TO GOOGLE CLOUD
    print("Saving data to Google Cloud Bucket")
    # ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  

    # Connect to Google Cloud Storage
    # -------------------------------
    storage_client = storage.Client()

    # Open Bucket
    # -----------
    bucket_name = 'weather_aurorabc'
    bucket = storage_client.bucket(bucket_name)

    # Save today's backup
    # -------------------
    mybuffer = io.BytesIO()
    data.to_csv(mybuffer, index=False)

    blob = bucket.blob('backups/weather_ampm-{}.csv'.format(datetime.today().date()))
    blob.upload_from_string(mybuffer.getvalue())

    # Update weather.csv
    # ------------------
    blob = bucket.blob('weather_ampm.csv')
    blob.upload_from_string(mybuffer.getvalue())

# %% [markdown]
# ---
# # Main
# ---

# %% [markdown]
# ## Import Data

# %%
# Import existing weather data from Google Cloud
# ----------------------------------------------
weather_data = import_weather_data()
print(weather_data.size)
# Out:
# 235200

# %%
for index, row in weather_data.iterrows():
    print("{}\n".format(row))
# Out:
# Date                         2020-01-01
# Station                      Port Hardy
# Time                                 AM
# Pressure                            700
# Height                           2856.0
# Temp                               -4.3
# DewPoint                           -5.8
# Relative_Humidity                  89.0
# Mean_Mixed_Layer                   3.56
# Wind_Direction                    250.0
# Wind_Speed                       87.044
# Potential_Temp                    297.7
# Equivalent_Potential_Temp         308.6
# Virtual_Potential_Temp            298.3
# Name: 0, dtype: object
#
# Date                         2020-01-01
# Station                      Port Hardy
# Time                                 AM
# Pressure                            850
# Height                           1301.0
# Temp                                3.4
# DewPoint                            1.9
# Relative_Humidity                  90.0
# Mean_Mixed_Layer                   5.19
# Wind_Direction                    250.0
# Wind_Speed                       59.264
# Potential_Temp                    289.7
# Equivalent_Potential_Temp         304.8
# Virtual_Potential_Temp            290.6
# Name: 1, dtype: object
#
# Date                         2020-01-01
# Station                      Port Hardy
# Time                                 PM
# Pressure                            700
# Height                           2857.0
# Temp                               -9.9
# DewPoint                          -17.9
# Relative_Humidity                  52.0
# Mean_Mixed_Layer                   1.34
# Wind_Direction                    280.0
# Wind_Speed                        64.82
# Potential_Temp                    291.5
# Equivalent_Potential_Temp         295.7
# Virtual_Potential_Temp            291.7
# Name: 2, dtype: object
#
# Date                         2020-01-01
# Station                      Port Hardy
# Time                                 PM
# Pressure                            850
# Height                           1328.0
# Temp                                0.4
# DewPoint                           -2.1
# Relative_Humidity                  83.0
# Mean_Mixed_Layer                   3.87
# Wind_Direction                    275.0
# Wind_Speed                       62.968
# Potential_Temp                    286.6
# Equivalent_Potential_Temp         297.8
# Virtual_Potential_Temp            287.2
# Name: 3, dtype: object
#
# Date                         2020-01-01
# Station                      Quillayute
# Time                                 AM
# Pressure                            700
# Height                           2969.0
# Temp                               -0.9
# DewPoint                           -0.9
# Relative_Humidity                 100.0
# Mean_Mixed_Layer                   5.14
# Wind_Direction                    255.0
# Wind_Speed                      100.008
# Potential_Temp                    301.5
# Equivalent_Potential_Temp         317.2
# Virtual_Potential_Temp            302.4
# Name: 4, dtype: object
#
# Date                         2020-01-01
# Station                      Quillayute
# Time                                 AM
# Pressure                            850
# Height                           1393.0
# Temp                                6.2
# DewPoint                            6.2
# Relative_Humidity                 100.0
# Mean_Mixed_Layer                   7.04
# Wind_Direction                    260.0
# Wind_Speed                       81.488
# Potential_Temp                    292.6
# Equivalent_Potential_Temp         313.1
# Virtual_Potential_Temp            293.9
# Name: 5, dtype: object
#
# Date                         2020-01-01
# Station                      Quillayute
# Time                                 PM
# Pressure                            700
# Height                           2925.0
# Temp                               -8.3
# DewPoint                          -21.3
# Relative_Humidity                  34.0
# Mean_Mixed_Layer                    1.0
# Wind_Direction                    280.0
# Wind_Speed                       68.524
# Potential_Temp                    293.3
# Equivalent_Potential_Temp         296.5
# Virtual_Potential_Temp            293.4
# Name: 6, dtype: object
#
# Date                         2020-01-01
# Station                      Quillayute
# Time                                 PM
# Pressure                            850
# Height                           1390.0
# Temp                                1.4
# DewPoint                            0.5
# Relative_Humidity                  94.0
# Mean_Mixed_Layer                   4.69
# Wind_Direction                    285.0
# Wind_Speed                       59.264
# Potential_Temp                    287.6
# Equivalent_Potential_Temp         301.2
# Virtual_Potential_Temp            288.4
# Name: 7, dtype: object
#
# Date                         2020-01-01
# Station                          Vernon
# Time                                 AM
# Pressure                            700
# Height                           2880.0
# Temp                               -5.5
# DewPoint                           -7.0
# Relative_Humidity                  89.0
# Mean_Mixed_Layer                   3.25
# Wind_Direction                    260.0
# Wind_Speed                       94.452
# Potential_Temp                    296.4
# Equivalent_Potential_Temp         306.3
# Virtual_Potential_Temp            296.9
# Name: 8, dtype: object
#
# Date                         2020-01-01
# Station                          Vernon
# Time                                 AM
# Pressure                            850
# Height                           1357.0
# Temp                               -3.9
# DewPoint                           -5.8
# Relative_Humidity                  87.0
# Mean_Mixed_Layer                   2.93
# Wind_Direction                    170.0
# Wind_Speed                        18.52
# Potential_Temp                    282.1
# Equivalent_Potential_Temp         290.5
# Virtual_Potential_Temp            282.6
# Name: 9, dtype: object
#
# Date                         2020-01-01
# Station                          Vernon
# Time                                 PM
# Pressure                            700
# Height                           2821.0
# Temp                               -6.5
# DewPoint                           -9.9
# Relative_Humidity                  77.0
# Mean_Mixed_Layer                   2.59
# Wind_Direction                    285.0
# Wind_Speed                       81.488
# Potential_Temp                    295.3
# Equivalent_Potential_Temp         303.2
# Virtual_Potential_Temp            295.7
# Name: 10, dtype: object
#
# Date                         2020-01-01
# Station                          Vernon
# Time                                 PM
# Pressure                            850
# Height                           1272.0
# Temp                                1.0
# DewPoint                            0.2
# Relative_Humidity                  94.0
# Mean_Mixed_Layer                   4.59
# Wind_Direction                    210.0
# Wind_Speed                       44.448
# Potential_Temp                    287.2
# Equivalent_Potential_Temp         300.4
# Virtual_Potential_Temp            288.0
# Name: 11, dtype: object
#
# Date                         2020-01-02
# Station                      Port Hardy
# Time                                 AM
# Pressure                            700
# Height                           2885.0
# Temp                              -15.3
# DewPoint                          -16.2
# Relative_Humidity                  93.0
# Mean_Mixed_Layer                   1.55
# Wind_Direction                    270.0
# Wind_Speed                       42.596
# Potential_Temp                    285.5
# Equivalent_Potential_Temp         290.2
# Virtual_Potential_Temp            285.8
# Name: 12, dtype: object
#
# Date                         2020-01-02
# Station                      Port Hardy
# Time                                 AM
# Pressure                            850
# Height                           1405.0
# Temp                               -5.7
# DewPoint                           -5.8
# Relative_Humidity                  99.0
# Mean_Mixed_Layer                   2.93
# Wind_Direction                    285.0
# Wind_Speed                       57.412
# Potential_Temp                    280.2
# Equivalent_Potential_Temp         288.6
# Virtual_Potential_Temp            280.7
# Name: 13, dtype: object
#
# Date                         2020-01-02
# Station                      Port Hardy
# Time                                 PM
# Pressure                            700
# Height                           2914.0
# Temp                              -16.3
# DewPoint                          -27.3
# Relative_Humidity                  38.0
# Mean_Mixed_Layer                   0.59
# Wind_Direction                    270.0
# Wind_Speed                         46.3
# Potential_Temp                    284.4
# Equivalent_Potential_Temp         286.3
# Virtual_Potential_Temp            284.5
# Name: 14, dtype: object
#
# Date                         2020-01-02
# Station                      Port Hardy
# Time                                 PM
# Pressure                            850
# Height                           1425.0
# Temp                               -7.1
# DewPoint                          -10.9
# Relative_Humidity                  74.0
# Mean_Mixed_Layer                   1.97
# Wind_Direction                    300.0
# Wind_Speed                       16.668
# Potential_Temp                    278.7
# Equivalent_Potential_Temp         284.4
# Virtual_Potential_Temp            279.0
# Name: 15, dtype: object
#
# Date                         2020-01-02
# Station                      Quillayute
# Time                                 AM
# Pressure                            700
# Height                           2946.0
# Temp                              -10.7
# DewPoint                          -23.7
# Relative_Humidity                  34.0
# Mean_Mixed_Layer                   0.81
# Wind_Direction                    260.0
# Wind_Speed                       50.004
# Potential_Temp                    290.6
# Equivalent_Potential_Temp         293.2
# Virtual_Potential_Temp            290.8
# Name: 16, dtype: object
#
# Date                         2020-01-02
# Station                      Quillayute
# Time                                 AM
# Pressure                            850
# Height                           1426.0
# Temp                               -1.3
# DewPoint                           -1.6
# Relative_Humidity                  98.0
# Mean_Mixed_Layer                   4.02
# Wind_Direction                    280.0
# Wind_Speed                       42.596
# Potential_Temp                    284.8
# Equivalent_Potential_Temp         296.4
# Virtual_Potential_Temp            285.5
# Name: 17, dtype: object
#
# Date                         2020-01-02
# Station                      Quillayute
# Time                                 PM
# Pressure                            700
# Height                           2973.0
# Temp                              -11.1
# DewPoint                          -50.1
# Relative_Humidity                   2.0
# Mean_Mixed_Layer                   0.06
# Wind_Direction                    290.0
# Wind_Speed                        64.82
# Potential_Temp                    290.2
# Equivalent_Potential_Temp         290.4
# Virtual_Potential_Temp            290.2
# Name: 18, dtype: object
#
# Date                         2020-01-02
# Station                      Quillayute
# Time                                 PM
# Pressure                            850
# Height                           1469.0
# Temp                               -4.5
# DewPoint                           -9.0
# Relative_Humidity                  71.0
# Mean_Mixed_Layer                   2.29
# Wind_Direction                    285.0
# Wind_Speed                       35.188
# Potential_Temp                    281.4
# Equivalent_Potential_Temp         288.1
# Virtual_Potential_Temp            281.8
# Name: 19, dtype: object
#
# Date                         2020-01-02
# Station                          Vernon
# Time                                 AM
# Pressure                            700
# Height                           2882.0
# Temp                               -9.5
# DewPoint                          -12.3
# Relative_Humidity                  80.0
# Mean_Mixed_Layer                   2.14
# Wind_Direction                    305.0
# Wind_Speed                       31.484
# Potential_Temp                    291.9
# Equivalent_Potential_Temp         298.5
# Virtual_Potential_Temp            292.3
# Name: 20, dtype: object
#
# Date                         2020-01-02
# Station                          Vernon
# Time                                 AM
# Pressure                            850
# Height                           1351.0
# Temp                                2.2
# DewPoint                           -4.8
# Relative_Humidity                  60.0
# Mean_Mixed_Layer                   3.16
# Wind_Direction                    245.0
# Wind_Speed                       33.336
# Potential_Temp                    288.4
# Equivalent_Potential_Temp         297.8
# Virtual_Potential_Temp            289.0
# Name: 21, dtype: object
#
# Date                         2020-01-02
# Station                          Vernon
# Time                                 PM
# Pressure                            700
# Height                           2907.0
# Temp                              -15.5
# DewPoint                          -18.4
# Relative_Humidity                  78.0
# Mean_Mixed_Layer                   1.29
# Wind_Direction                    300.0
# Wind_Speed                       61.116
# Potential_Temp                    285.3
# Equivalent_Potential_Temp         289.3
# Virtual_Potential_Temp            285.5
# Name: 22, dtype: object
#
# Date                         2020-01-02
# Station                          Vernon
# Time                                 PM
# Pressure                            850
# Height                           1408.0
# Temp                               -3.9
# DewPoint                          -13.9
# Relative_Humidity                  46.0
# Mean_Mixed_Layer                   1.54
# Wind_Direction                    340.0
# Wind_Speed                        27.78
# Potential_Temp                    282.1
# Equivalent_Potential_Temp         286.7
# Virtual_Potential_Temp            282.3
# Name: 23, dtype: object
#
# Date                         2020-01-03
# Station                      Port Hardy
# Time                                 AM
# Pressure                            700
# Height                           2889.0
# Temp                               -2.9
# DewPoint                           -4.7
# Relative_Humidity                  87.0
# Mean_Mixed_Layer                   3.87
# Wind_Direction                    245.0
# Wind_Speed                         92.6
# Potential_Temp                    299.2
# Equivalent_Potential_Temp         311.1
# Virtual_Potential_Temp            299.9
# Name: 24, dtype: object
#
# Date                         2020-01-03
# Station                      Port Hardy
# Time                                 AM
# Pressure                            850
# Height                           1344.0
# Temp                               -3.3
# DewPoint                           -4.8
# Relative_Humidity                  89.0
# Mean_Mixed_Layer                   3.16
# Wind_Direction                    160.0
# Wind_Speed                       61.116
# Potential_Temp                    282.7
# Equivalent_Potential_Temp         291.8
# Virtual_Potential_Temp            283.2
# Name: 25, dtype: object
#
# Date                         2020-01-03
# Station                      Port Hardy
# Time                                 PM
# Pressure                            700
# Height                           2878.0
# Temp                               -0.9
# DewPoint                           -2.0
# Relative_Humidity                  92.0
# Mean_Mixed_Layer                   4.74
# Wind_Direction                    230.0
# Wind_Speed                      103.712
# Potential_Temp                    301.5
# Equivalent_Potential_Temp         316.0
# Virtual_Potential_Temp            302.3
# Name: 26, dtype: object
#
# Date                         2020-01-03
# Station                      Port Hardy
# Time                                 PM
# Pressure                            850
# Height                           1309.0
# Temp                                5.2
# DewPoint                            4.4
# Relative_Humidity                  95.0
# Mean_Mixed_Layer                    6.2
# Wind_Direction                    220.0
# Wind_Speed                        64.82
# Potential_Temp                    291.6
# Equivalent_Potential_Temp         309.6
# Virtual_Potential_Temp            292.7
# Name: 27, dtype: object
#
# Date                         2020-01-03
# Station                      Quillayute
# Time                                 AM
# Pressure                            700
# Height                           2974.0
# Temp                               -2.3
# DewPoint                           -2.7
# Relative_Humidity                  97.0
# Mean_Mixed_Layer                    4.5
# Wind_Direction                    270.0
# Wind_Speed                       90.748
# Potential_Temp                    299.9
# Equivalent_Potential_Temp         313.6
# Virtual_Potential_Temp            300.7
# Name: 28, dtype: object
#
# Date                         2020-01-03
# Station                      Quillayute
# Time                                 AM
# Pressure                            850
# Height                           1423.0
# Temp                                1.8
# DewPoint                            1.7
# Relative_Humidity                  99.0
# Mean_Mixed_Layer                   5.12
# Wind_Direction                    215.0
# Wind_Speed                       79.636
# Potential_Temp                    288.0
# Equivalent_Potential_Temp         302.8
# Virtual_Potential_Temp            288.9
# Name: 29, dtype: object
#
# Date                         2020-01-03
# Station                      Quillayute
# Time                                 PM
# Pressure                            700
# Height                           2998.0
# Temp                               -2.7
# DewPoint                           -6.2
# Relative_Humidity                  77.0
# Mean_Mixed_Layer                   3.45
# Wind_Direction                    245.0
# Wind_Speed                       77.784
# Potential_Temp                    299.5
# Equivalent_Potential_Temp         310.1
# Virtual_Potential_Temp            300.1
# Name: 30, dtype: object
#
# Date                         2020-01-03
# Station                      Quillayute
# Time                                 PM
# Pressure                            850
# Height                           1427.0
# Temp                                6.0
# DewPoint                            5.9
# Relative_Humidity                  99.0
# Mean_Mixed_Layer                   6.89
# Wind_Direction                    215.0
# Wind_Speed                       70.376
# Potential_Temp                    292.4
# Equivalent_Potential_Temp         312.4
# Virtual_Potential_Temp            293.6
# Name: 31, dtype: object
#
# Date                         2020-01-03
# Station                          Vernon
# Time                                 AM
# Pressure                            700
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 32, dtype: object
#
# Date                         2020-01-03
# Station                          Vernon
# Time                                 AM
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 33, dtype: object
#
# Date                         2020-01-03
# Station                          Vernon
# Time                                 PM
# Pressure                            700
# Height                           2922.0
# Temp                               -6.7
# DewPoint                           -8.4
# Relative_Humidity                  88.0
# Mean_Mixed_Layer                   2.91
# Wind_Direction                    245.0
# Wind_Speed                      107.416
# Potential_Temp                    295.0
# Equivalent_Potential_Temp         303.9
# Virtual_Potential_Temp            295.6
# Name: 34, dtype: object
#
# Date                         2020-01-03
# Station                          Vernon
# Time                                 PM
# Pressure                            850
# Height                           1402.0
# Temp                               -4.7
# DewPoint                           -7.0
# Relative_Humidity                  84.0
# Mean_Mixed_Layer                   2.67
# Wind_Direction                    175.0
# Wind_Speed                       11.112
# Potential_Temp                    281.2
# Equivalent_Potential_Temp         289.0
# Virtual_Potential_Temp            281.7
# Name: 35, dtype: object
#
# Date                         2020-01-04
# Station                      Port Hardy
# Time                                 AM
# Pressure                            700
# Height                           2791.0
# Temp                               -5.3
# DewPoint                           -6.9
# Relative_Humidity                  89.0
# Mean_Mixed_Layer                   3.27
# Wind_Direction                    200.0
# Wind_Speed                      124.084
# Potential_Temp                    296.6
# Equivalent_Potential_Temp         306.6
# Virtual_Potential_Temp            297.2
# Name: 36, dtype: object
#
# Date                         2020-01-04
# Station                      Port Hardy
# Time                                 AM
# Pressure                            850
# Height                           1244.0
# Temp                                2.4
# DewPoint                            0.3
# Relative_Humidity                  86.0
# Mean_Mixed_Layer                   4.62
# Wind_Direction                    195.0
# Wind_Speed                       88.896
# Potential_Temp                    288.6
# Equivalent_Potential_Temp         302.1
# Virtual_Potential_Temp            289.4
# Name: 37, dtype: object
#
# Date                         2020-01-04
# Station                      Port Hardy
# Time                                 PM
# Pressure                            700
# Height                           2852.0
# Temp                              -17.1
# DewPoint                          -22.1
# Relative_Humidity                  65.0
# Mean_Mixed_Layer                   0.94
# Wind_Direction                    250.0
# Wind_Speed                       68.524
# Potential_Temp                    283.5
# Equivalent_Potential_Temp         286.4
# Virtual_Potential_Temp            283.7
# Name: 38, dtype: object
#
# Date                         2020-01-04
# Station                      Port Hardy
# Time                                 PM
# Pressure                            850
# Height                           1369.0
# Temp                               -6.1
# DewPoint                          -10.2
# Relative_Humidity                  73.0
# Mean_Mixed_Layer                   2.08
# Wind_Direction                    255.0
# Wind_Speed                       68.524
# Potential_Temp                    279.7
# Equivalent_Potential_Temp         285.8
# Virtual_Potential_Temp            280.1
# Name: 39, dtype: object
#
# Date                         2020-01-04
# Station                      Quillayute
# Time                                 AM
# Pressure                            700
# Height                           2942.0
# Temp                               -4.5
# DewPoint                          -20.5
# Relative_Humidity                  27.0
# Mean_Mixed_Layer                   1.08
# Wind_Direction                    215.0
# Wind_Speed                      112.972
# Potential_Temp                    297.5
# Equivalent_Potential_Temp         301.0
# Virtual_Potential_Temp            297.7
# Name: 40, dtype: object
#
# Date                         2020-01-04
# Station                      Quillayute
# Time                                 AM
# Pressure                            850
# Height                           1387.0
# Temp                                5.2
# DewPoint                            5.1
# Relative_Humidity                  99.0
# Mean_Mixed_Layer                   6.52
# Wind_Direction                    210.0
# Wind_Speed                      105.564
# Potential_Temp                    291.6
# Equivalent_Potential_Temp         310.5
# Virtual_Potential_Temp            292.7
# Name: 41, dtype: object
#
# Date                         2020-01-04
# Station                      Quillayute
# Time                                 PM
# Pressure                            700
# Height                           2926.0
# Temp                              -15.9
# DewPoint                          -24.9
# Relative_Humidity                  46.0
# Mean_Mixed_Layer                   0.73
# Wind_Direction                    265.0
# Wind_Speed                       70.376
# Potential_Temp                    284.9
# Equivalent_Potential_Temp         287.2
# Virtual_Potential_Temp            285.0
# Name: 42, dtype: object
#
# Date                         2020-01-04
# Station                      Quillayute
# Time                                 PM
# Pressure                            850
# Height                           1432.0
# Temp                               -4.3
# DewPoint                          -10.3
# Relative_Humidity                  63.0
# Mean_Mixed_Layer                   2.06
# Wind_Direction                    270.0
# Wind_Speed                        55.56
# Potential_Temp                    281.6
# Equivalent_Potential_Temp         287.7
# Virtual_Potential_Temp            282.0
# Name: 43, dtype: object
#
# Date                         2020-01-04
# Station                          Vernon
# Time                                 AM
# Pressure                            700
# Height                           2937.0
# Temp                               -5.7
# DewPoint                          -10.7
# Relative_Humidity                  68.0
# Mean_Mixed_Layer                   2.43
# Wind_Direction                    235.0
# Wind_Speed                       87.044
# Potential_Temp                    296.1
# Equivalent_Potential_Temp         303.7
# Virtual_Potential_Temp            296.6
# Name: 44, dtype: object
#
# Date                         2020-01-04
# Station                          Vernon
# Time                                 AM
# Pressure                            850
# Height                           1411.0
# Temp                                0.6
# DewPoint                           -2.7
# Relative_Humidity                  79.0
# Mean_Mixed_Layer                    3.7
# Wind_Direction                    140.0
# Wind_Speed                         9.26
# Potential_Temp                    286.8
# Equivalent_Potential_Temp         297.6
# Virtual_Potential_Temp            287.4
# Name: 45, dtype: object
#
# Date                         2020-01-04
# Station                          Vernon
# Time                                 PM
# Pressure                            700
# Height                           2873.0
# Temp                               -9.3
# DewPoint                          -12.8
# Relative_Humidity                  76.0
# Mean_Mixed_Layer                   2.05
# Wind_Direction                    250.0
# Wind_Speed                       59.264
# Potential_Temp                    292.2
# Equivalent_Potential_Temp         298.5
# Virtual_Potential_Temp            292.5
# Name: 46, dtype: object
#
# Date                         2020-01-04
# Station                          Vernon
# Time                                 PM
# Pressure                            850
# Height                           1349.0
# Temp                                1.4
# DewPoint                           -3.6
# Relative_Humidity                  69.0
# Mean_Mixed_Layer                   3.46
# Wind_Direction                    205.0
# Wind_Speed                       66.672
# Potential_Temp                    287.6
# Equivalent_Potential_Temp         297.8
# Virtual_Potential_Temp            288.2
# Name: 47, dtype: object
#
# Date                         2020-01-05
# Station                      Port Hardy
# Time                                 AM
# Pressure                            700
# Height                           2941.0
# Temp                              -15.1
# DewPoint                          -23.1
# Relative_Humidity                  50.0
# Mean_Mixed_Layer                   0.86
# Wind_Direction                    245.0
# Wind_Speed                        64.82
# Potential_Temp                    285.7
# Equivalent_Potential_Temp         288.4
# Virtual_Potential_Temp            285.9
# Name: 48, dtype: object
#
# Date                         2020-01-05
# Station                      Port Hardy
# Time                                 AM
# Pressure                            850
# Height                           1449.0
# Temp                               -5.3
# DewPoint                           -7.4
# Relative_Humidity                  85.0
# Mean_Mixed_Layer                   2.59
# Wind_Direction                    220.0
# Wind_Speed                       44.448
# Potential_Temp                    280.6
# Equivalent_Potential_Temp         288.1
# Virtual_Potential_Temp            281.0
# Name: 49, dtype: object
#
# Date                         2020-01-05
# Station                      Port Hardy
# Time                                 PM
# Pressure                            700
# Height                           2910.0
# Temp                              -11.3
# DewPoint                          -14.8
# Relative_Humidity                  75.0
# Mean_Mixed_Layer                   1.74
# Wind_Direction                    205.0
# Wind_Speed                       94.452
# Potential_Temp                    289.9
# Equivalent_Potential_Temp         295.3
# Virtual_Potential_Temp            290.2
# Name: 50, dtype: object
#
# Date                         2020-01-05
# Station                      Port Hardy
# Time                                 PM
# Pressure                            850
# Height                           1398.0
# Temp                               -2.3
# DewPoint                           -4.2
# Relative_Humidity                  87.0
# Mean_Mixed_Layer                   3.31
# Wind_Direction                    185.0
# Wind_Speed                       79.636
# Potential_Temp                    283.7
# Equivalent_Potential_Temp         293.3
# Virtual_Potential_Temp            284.3
# Name: 51, dtype: object
#
# Date                         2020-01-05
# Station                      Quillayute
# Time                                 AM
# Pressure                            700
# Height                           3015.0
# Temp                              -14.1
# DewPoint                          -16.3
# Relative_Humidity                  83.0
# Mean_Mixed_Layer                   1.54
# Wind_Direction                    240.0
# Wind_Speed                       75.932
# Potential_Temp                    286.8
# Equivalent_Potential_Temp         291.6
# Virtual_Potential_Temp            287.1
# Name: 52, dtype: object
#
# Date                         2020-01-05
# Station                      Quillayute
# Time                                 AM
# Pressure                            850
# Height                           1513.0
# Temp                               -4.3
# DewPoint                           -5.1
# Relative_Humidity                  94.0
# Mean_Mixed_Layer                   3.09
# Wind_Direction                    215.0
# Wind_Speed                         46.3
# Potential_Temp                    281.6
# Equivalent_Potential_Temp         290.5
# Virtual_Potential_Temp            282.2
# Name: 53, dtype: object
#
# Date                         2020-01-05
# Station                      Quillayute
# Time                                 PM
# Pressure                            700
# Height                           2998.0
# Temp                              -12.9
# DewPoint                          -13.5
# Relative_Humidity                  95.0
# Mean_Mixed_Layer                   1.94
# Wind_Direction                    220.0
# Wind_Speed                        64.82
# Potential_Temp                    288.2
# Equivalent_Potential_Temp         294.1
# Virtual_Potential_Temp            288.5
# Name: 54, dtype: object
#
# Date                         2020-01-05
# Station                      Quillayute
# Time                                 PM
# Pressure                            850
# Height                           1484.0
# Temp                               -2.3
# DewPoint                           -3.7
# Relative_Humidity                  90.0
# Mean_Mixed_Layer                   3.44
# Wind_Direction                    205.0
# Wind_Speed                        64.82
# Potential_Temp                    283.7
# Equivalent_Potential_Temp         293.7
# Virtual_Potential_Temp            284.3
# Name: 55, dtype: object
#
# Date                         2020-01-05
# Station                          Vernon
# Time                                 AM
# Pressure                            700
# Height                           2974.0
# Temp                              -15.1
# DewPoint                          -24.1
# Relative_Humidity                  46.0
# Mean_Mixed_Layer                   0.78
# Wind_Direction                    285.0
# Wind_Speed                       68.524
# Potential_Temp                    285.7
# Equivalent_Potential_Temp         288.2
# Virtual_Potential_Temp            285.9
# Name: 56, dtype: object
#
# Date                         2020-01-05
# Station                          Vernon
# Time                                 AM
# Pressure                            850
# Height                           1477.0
# Temp                               -3.1
# DewPoint                          -12.1
# Relative_Humidity                  50.0
# Mean_Mixed_Layer                   1.79
# Wind_Direction                    220.0
# Wind_Speed                       24.076
# Potential_Temp                    282.9
# Equivalent_Potential_Temp         288.2
# Virtual_Potential_Temp            283.2
# Name: 57, dtype: object
#
# Date                         2020-01-05
# Station                          Vernon
# Time                                 PM
# Pressure                            700
# Height                           2996.0
# Temp                              -14.3
# DewPoint                          -17.4
# Relative_Humidity                  77.0
# Mean_Mixed_Layer                    1.4
# Wind_Direction                    245.0
# Wind_Speed                       59.264
# Potential_Temp                    286.6
# Equivalent_Potential_Temp         290.9
# Virtual_Potential_Temp            286.9
# Name: 58, dtype: object
#
# Date                         2020-01-05
# Station                          Vernon
# Time                                 PM
# Pressure                            850
# Height                           1491.0
# Temp                               -4.1
# DewPoint                           -9.1
# Relative_Humidity                  68.0
# Mean_Mixed_Layer                   2.27
# Wind_Direction                    185.0
# Wind_Speed                        18.52
# Potential_Temp                    281.8
# Equivalent_Potential_Temp         288.5
# Virtual_Potential_Temp            282.2
# Name: 59, dtype: object
#
# Date                         2020-01-06
# Station                      Port Hardy
# Time                                 AM
# Pressure                            700
# Height                           2920.0
# Temp                              -18.1
# DewPoint                          -20.5
# Relative_Humidity                  81.0
# Mean_Mixed_Layer                   1.08
# Wind_Direction                    280.0
# Wind_Speed                       53.708
# Potential_Temp                    282.4
# Equivalent_Potential_Temp         285.7
# Virtual_Potential_Temp            282.6
# Name: 60, dtype: object
#
# Date                         2020-01-06
# Station                      Port Hardy
# Time                                 AM
# Pressure                            850
# Height                           1457.0
# Temp                               -5.9
# DewPoint                          -10.9
# Relative_Humidity                  68.0
# Mean_Mixed_Layer                   1.97
# Wind_Direction                    280.0
# Wind_Speed                       44.448
# Potential_Temp                    279.9
# Equivalent_Potential_Temp         285.7
# Virtual_Potential_Temp            280.3
# Name: 61, dtype: object
#
# Date                         2020-01-06
# Station                      Port Hardy
# Time                                 PM
# Pressure                            700
# Height                           2979.0
# Temp                              -10.1
# DewPoint                          -11.7
# Relative_Humidity                  88.0
# Mean_Mixed_Layer                   2.24
# Wind_Direction                    265.0
# Wind_Speed                       53.708
# Potential_Temp                    291.3
# Equivalent_Potential_Temp         298.1
# Virtual_Potential_Temp            291.7
# Name: 62, dtype: object
#
# Date                         2020-01-06
# Station                      Port Hardy
# Time                                 PM
# Pressure                            850
# Height                           1459.0
# Temp                               -2.1
# DewPoint                           -4.7
# Relative_Humidity                  82.0
# Mean_Mixed_Layer                   3.19
# Wind_Direction                    195.0
# Wind_Speed                       29.632
# Potential_Temp                    283.9
# Equivalent_Potential_Temp         293.2
# Virtual_Potential_Temp            284.5
# Name: 63, dtype: object
#
# Date                         2020-01-06
# Station                      Quillayute
# Time                                 AM
# Pressure                            700
# Height                           3011.0
# Temp                              -15.1
# DewPoint                          -24.1
# Relative_Humidity                  46.0
# Mean_Mixed_Layer                   0.78
# Wind_Direction                    275.0
# Wind_Speed                        74.08
# Potential_Temp                    285.7
# Equivalent_Potential_Temp         288.2
# Virtual_Potential_Temp            285.9
# Name: 64, dtype: object
#
# Date                         2020-01-06
# Station                      Quillayute
# Time                                 AM
# Pressure                            850
# Height                           1514.0
# Temp                               -5.1
# DewPoint                           -9.5
# Relative_Humidity                  71.0
# Mean_Mixed_Layer                    2.2
# Wind_Direction                    265.0
# Wind_Speed                       44.448
# Potential_Temp                    280.8
# Equivalent_Potential_Temp         287.2
# Virtual_Potential_Temp            281.2
# Name: 65, dtype: object
#
# Date                         2020-01-06
# Station                      Quillayute
# Time                                 PM
# Pressure                            700
# Height                           3031.0
# Temp                               -7.5
# DewPoint                           -7.7
# Relative_Humidity                  98.0
# Mean_Mixed_Layer                   3.07
# Wind_Direction                    255.0
# Wind_Speed                       75.932
# Potential_Temp                    294.1
# Equivalent_Potential_Temp         303.5
# Virtual_Potential_Temp            294.7
# Name: 66, dtype: object
#
# Date                         2020-01-06
# Station                      Quillayute
# Time                                 PM
# Pressure                            850
# Height                           1493.0
# Temp                                1.0
# DewPoint                            1.0
# Relative_Humidity                 100.0
# Mean_Mixed_Layer                   4.86
# Wind_Direction                    235.0
# Wind_Speed                       70.376
# Potential_Temp                    287.2
# Equivalent_Potential_Temp         301.2
# Virtual_Potential_Temp            288.0
# Name: 67, dtype: object
#
# Date                         2020-01-06
# Station                          Vernon
# Time                                 AM
# Pressure                            700
# Height                           2927.0
# Temp                              -12.7
# DewPoint                          -14.7
# Relative_Humidity                  85.0
# Mean_Mixed_Layer                   1.76
# Wind_Direction                    225.0
# Wind_Speed                       81.488
# Potential_Temp                    288.4
# Equivalent_Potential_Temp         293.8
# Virtual_Potential_Temp            288.7
# Name: 68, dtype: object
#
# Date                         2020-01-06
# Station                          Vernon
# Time                                 AM
# Pressure                            850
# Height                           1432.0
# Temp                               -3.1
# DewPoint                           -7.1
# Relative_Humidity                  74.0
# Mean_Mixed_Layer                   2.65
# Wind_Direction                    190.0
# Wind_Speed                       24.076
# Potential_Temp                    282.9
# Equivalent_Potential_Temp         290.6
# Virtual_Potential_Temp            283.3
# Name: 69, dtype: object
#
# Date                         2020-01-06
# Station                          Vernon
# Time                                 PM
# Pressure                            700
# Height                           2969.0
# Temp                              -16.7
# DewPoint                          -21.4
# Relative_Humidity                  67.0
# Mean_Mixed_Layer                   0.99
# Wind_Direction                    280.0
# Wind_Speed                       42.596
# Potential_Temp                    284.0
# Equivalent_Potential_Temp         287.1
# Virtual_Potential_Temp            284.1
# Name: 70, dtype: object
#
# Date                         2020-01-06
# Station                          Vernon
# Time                                 PM
# Pressure                            850
# Height                           1482.0
# Temp                               -5.5
# DewPoint                          -10.4
# Relative_Humidity                  68.0
# Mean_Mixed_Layer                   2.05
# Wind_Direction                    205.0
# Wind_Speed                        27.78
# Potential_Temp                    280.4
# Equivalent_Potential_Temp         286.4
# Virtual_Potential_Temp            280.7
# Name: 71, dtype: object
#
# Date                         2020-01-07
# Station                      Port Hardy
# Time                                 AM
# Pressure                            700
# Height                           2958.0
# Temp                               -8.1
# DewPoint                          -13.0
# Relative_Humidity                  68.0
# Mean_Mixed_Layer                   2.02
# Wind_Direction                    265.0
# Wind_Speed                        64.82
# Potential_Temp                    293.5
# Equivalent_Potential_Temp         299.8
# Virtual_Potential_Temp            293.8
# Name: 72, dtype: object
#
# Date                         2020-01-07
# Station                      Port Hardy
# Time                                 AM
# Pressure                            850
# Height                           1432.0
# Temp                               -0.9
# DewPoint                           -3.3
# Relative_Humidity                  84.0
# Mean_Mixed_Layer                   3.54
# Wind_Direction                    255.0
# Wind_Speed                       14.816
# Potential_Temp                    285.2
# Equivalent_Potential_Temp         295.5
# Virtual_Potential_Temp            285.8
# Name: 73, dtype: object
#
# Date                         2020-01-07
# Station                      Port Hardy
# Time                                 PM
# Pressure                            700
# Height                           2892.0
# Temp                               -5.5
# DewPoint                           -7.5
# Relative_Humidity                  86.0
# Mean_Mixed_Layer                   3.12
# Wind_Direction                    210.0
# Wind_Speed                       72.228
# Potential_Temp                    296.4
# Equivalent_Potential_Temp         305.9
# Virtual_Potential_Temp            296.9
# Name: 74, dtype: object
#
# Date                         2020-01-07
# Station                      Port Hardy
# Time                                 PM
# Pressure                            850
# Height                           1354.0
# Temp                                1.2
# DewPoint                           -0.4
# Relative_Humidity                  89.0
# Mean_Mixed_Layer                   4.39
# Wind_Direction                    160.0
# Wind_Speed                       35.188
# Potential_Temp                    287.4
# Equivalent_Potential_Temp         300.1
# Virtual_Potential_Temp            288.1
# Name: 75, dtype: object
#
# Date                         2020-01-07
# Station                      Quillayute
# Time                                 AM
# Pressure                            700
# Height                           3035.0
# Temp                               -5.3
# DewPoint                           -5.5
# Relative_Humidity                  98.0
# Mean_Mixed_Layer                   3.64
# Wind_Direction                    265.0
# Wind_Speed                        64.82
# Potential_Temp                    296.6
# Equivalent_Potential_Temp         307.7
# Virtual_Potential_Temp            297.2
# Name: 76, dtype: object
#
# Date                         2020-01-07
# Station                      Quillayute
# Time                                 AM
# Pressure                            850
# Height                           1486.0
# Temp                                3.0
# DewPoint                            2.9
# Relative_Humidity                  99.0
# Mean_Mixed_Layer                   5.58
# Wind_Direction                    260.0
# Wind_Speed                       51.856
# Potential_Temp                    289.3
# Equivalent_Potential_Temp         305.4
# Virtual_Potential_Temp            290.2
# Name: 77, dtype: object
#
# Date                         2020-01-07
# Station                      Quillayute
# Time                                 PM
# Pressure                            700
# Height                           2999.0
# Temp                               -6.5
# DewPoint                           -6.9
# Relative_Humidity                  97.0
# Mean_Mixed_Layer                   3.27
# Wind_Direction                    225.0
# Wind_Speed                       66.672
# Potential_Temp                    295.3
# Equivalent_Potential_Temp         305.2
# Virtual_Potential_Temp            295.8
# Name: 78, dtype: object
#
# Date                         2020-01-07
# Station                      Quillayute
# Time                                 PM
# Pressure                            850
# Height                           1451.0
# Temp                                3.2
# DewPoint                            3.2
# Relative_Humidity                 100.0
# Mean_Mixed_Layer                    5.7
# Wind_Direction                    225.0
# Wind_Speed                       66.672
# Potential_Temp                    289.5
# Equivalent_Potential_Temp         305.9
# Virtual_Potential_Temp            290.5
# Name: 79, dtype: object
#
# Date                         2020-01-07
# Station                          Vernon
# Time                                 AM
# Pressure                            700
# Height                           2951.0
# Temp                               -9.9
# DewPoint                          -11.8
# Relative_Humidity                  86.0
# Mean_Mixed_Layer                   2.22
# Wind_Direction                    280.0
# Wind_Speed                         46.3
# Potential_Temp                    291.5
# Equivalent_Potential_Temp         298.3
# Virtual_Potential_Temp            291.9
# Name: 80, dtype: object
#
# Date                         2020-01-07
# Station                          Vernon
# Time                                 AM
# Pressure                            850
# Height                           1440.0
# Temp                               -5.7
# DewPoint                           -7.9
# Relative_Humidity                  84.0
# Mean_Mixed_Layer                   2.49
# Wind_Direction                    205.0
# Wind_Speed                       24.076
# Potential_Temp                    280.2
# Equivalent_Potential_Temp         287.4
# Virtual_Potential_Temp            280.6
# Name: 81, dtype: object
#
# Date                         2020-01-07
# ...
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4548, dtype: object
#
# Date                         2021-01-14
# Station                      Port Hardy
# Time                                 AM
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4549, dtype: object
#
# Date                         2021-01-14
# Station                      Port Hardy
# Time                                 PM
# Pressure                            700
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4550, dtype: object
#
# Date                         2021-01-14
# Station                      Port Hardy
# Time                                 PM
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4551, dtype: object
#
# Date                         2021-01-14
# Station                      Quillayute
# Time                                 AM
# Pressure                            700
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4552, dtype: object
#
# Date                         2021-01-14
# Station                      Quillayute
# Time                                 AM
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4553, dtype: object
#
# Date                         2021-01-14
# Station                      Quillayute
# Time                                 PM
# Pressure                            700
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4554, dtype: object
#
# Date                         2021-01-14
# Station                      Quillayute
# Time                                 PM
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4555, dtype: object
#
# Date                         2021-01-14
# Station                          Vernon
# Time                                 AM
# Pressure                            700
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4556, dtype: object
#
# Date                         2021-01-14
# Station                          Vernon
# Time                                 AM
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4557, dtype: object
#
# Date                         2021-01-14
# Station                          Vernon
# Time                                 PM
# Pressure                            700
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4558, dtype: object
#
# Date                         2021-01-14
# Station                          Vernon
# Time                                 PM
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4559, dtype: object
#
# Date                         2021-01-15
# Station                      Port Hardy
# Time                                 AM
# Pressure                            700
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4560, dtype: object
#
# Date                         2021-01-15
# Station                      Port Hardy
# Time                                 AM
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4561, dtype: object
#
# Date                         2021-01-15
# Station                      Port Hardy
# Time                                 PM
# Pressure                            700
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4562, dtype: object
#
# Date                         2021-01-15
# Station                      Port Hardy
# Time                                 PM
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4563, dtype: object
#
# Date                         2021-01-15
# Station                      Quillayute
# Time                                 AM
# Pressure                            700
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4564, dtype: object
#
# Date                         2021-01-15
# Station                      Quillayute
# Time                                 AM
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4565, dtype: object
#
# Date                         2021-01-15
# Station                      Quillayute
# Time                                 PM
# Pressure                            700
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4566, dtype: object
#
# Date                         2021-01-15
# Station                      Quillayute
# Time                                 PM
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4567, dtype: object
#
# Date                         2021-01-15
# Station                          Vernon
# Time                                 AM
# Pressure                            700
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4568, dtype: object
#
# Date                         2021-01-15
# Station                          Vernon
# Time                                 AM
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4569, dtype: object
#
# Date                         2021-01-15
# Station                          Vernon
# Time                                 PM
# Pressure                            700
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4570, dtype: object
#
# Date                         2021-01-15
# Station                          Vernon
# Time                                 PM
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4571, dtype: object
#
# Date                         2021-01-16
# Station                      Port Hardy
# Time                                 AM
# Pressure                            700
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4572, dtype: object
#
# Date                         2021-01-16
# Station                      Port Hardy
# Time                                 AM
# Pressure                            850
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4573, dtype: object
#
# Date                         2021-01-16
# Station                      Port Hardy
# Time                                 PM
# Pressure                            700
# Height                              NaN
# Temp                                NaN
# DewPoint                            NaN
# Relative_Humidity                   NaN
# Mean_Mixed_Layer                    NaN
# Wind_Direction                      NaN
# Wind_Speed                          NaN
# Potential_Temp                      NaN
# Equivalent_Potential_Temp           NaN
# Virtual_Potential_Temp              NaN
# Name: 4574, dtype: object
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Find Missing Data

# %%
# Find missing or 'nan' values within current dataset
# ---------------------------------------------------
missing_data = find_missing_vals(weather_data)
print(len(missing_data))
# Out:
# 1315

# %%
for row in missing_data:
    print(row)
    print("\n")
# Out:
# {'date': '2020-01-03', 'stations': [{'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-01-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-18', 'stations': [{'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-02-20', 'stations': [{'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-06', 'stations': [{'id': 73033, 'name': 'Vernon', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-24', 'stations': [{'id': 73033, 'name': 'Vernon', 'pressures': ['850']}]}
#
#
# {'date': '2020-03-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-02', 'stations': [{'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-03', 'stations': [{'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-08', 'stations': [{'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-09', 'stations': [{'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-17', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-18', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-19', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-04-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-17', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-18', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-19', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-05-31', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-17', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-18', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-19', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-06-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-17', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-18', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-19', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-07-31', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-08-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-08-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-08-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-08-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-08-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2020-08-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# ...
#
#
# {'date': '2023-09-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-09-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-09-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-09-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-09-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-09-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-09-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-09-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-09-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-09-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-01', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-02', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-03', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-04', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-05', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-06', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-07', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-08', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-09', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-10', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-11', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-12', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-13', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-14', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-15', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-16', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-17', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-18', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-19', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-20', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-21', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-22', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-23', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-24', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-25', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-26', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-27', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-28', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-29', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-30', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}
#
#
# {'date': '2023-10-31', 'stations': [{'id': 72797, 'name': 'Quillayute', 'pressures': ['700']}, {'id': 72797, 'name': 'Quillayute', 'pressures': ['850']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['700']}, {'id': 73033, 'name': 'Vernon', 'pressures': ['850']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['700']}, {'id': 71109, 'name': 'Port Hardy', 'pressures': ['850']}]}

# %% [markdown]
# ## Get New Data

# %%
# Scrape weather balloons for new data within defined date range
# --------------------------------------------------------------
#new_data = scrape_data(dates)
new_data = scrape_data(missing_data[:25])
print(new_data.size)
# Out:
# Creating list of URLs to be scraped
# Creating dates list...
# Extracting data from list of URLs
# on 10: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=02&FROM=0300&TO=0311&STNM=72797&REPLOT=1
# on 12: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=02&FROM=0300&TO=0311&STNM=72797&REPLOT=1
# on 25: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=03&FROM=2012&TO=2023&STNM=72797&REPLOT=1
# on 27: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=03&FROM=2012&TO=2023&STNM=72797&REPLOT=1
# on 41: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=03&FROM=3012&TO=3023&STNM=71109&REPLOT=1
# on 43: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=03&FROM=3012&TO=3023&STNM=71109&REPLOT=1
# on 44: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=04&FROM=0200&TO=0211&STNM=73033&REPLOT=1
# on 45: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=04&FROM=0212&TO=0223&STNM=73033&REPLOT=1
# on 47: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=04&FROM=0212&TO=0223&STNM=73033&REPLOT=1
# on 48: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=04&FROM=0300&TO=0311&STNM=73033&REPLOT=1
# on 50: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=04&FROM=0300&TO=0311&STNM=73033&REPLOT=1
# on 52: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=04&FROM=0300&TO=0311&STNM=71109&REPLOT=1
# on 54: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=04&FROM=0300&TO=0311&STNM=71109&REPLOT=1
# on 57: http://weather.uwyo.edu/cgi-bin/sounding?region=naconf&TYPE=TEXT%3ALIST&YEAR=2020&MONTH=04&FROM=0812&TO=0823&STNM=73033&REPLOT=1
# |█████████████▊⚠︎                         | (!) 59/172 [34%] in 3:20.7 (0.29/s)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[333], line 4
#       1 # Scrape weather balloons for new data within defined date range
#       2 # --------------------------------------------------------------
#       3 #new_data = scrape_data(dates)
# ----> 4 new_data = scrape_data(missing_data[:25])
#       5 print(new_data.size)
#
# Cell In[249], line 62, in scrape_data(missing_vals)
#      58 while search >= 0:
#      59     # Scrape site data
#      60     # ~~~~~~~~~~~~~~~~
#      61     search += 1
# ---> 62     page = requests.get(url)
#      63     soup = BeautifulSoup(page.content, "html.parser")
#      64     results = str(soup.find('pre'))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
new_data.dropna(subset=['Temp', 'Wind_Speed'])
new_data.head(10)

# %% [markdown]
# ### Standardize DataTypes

# %%
new_data = standardize_dtypes(new_data)
new_data.head(10)

# %%
new_data.dtypes

# %%
# Convert wind speed from Knots to KM/H
# -------------------------------------
new_data['Wind_Speed'] = new_data['Wind_Speed'].multiply(1.852)
new_data.head(10)

# %% [markdown]
# ## Combine New and Old Data

# %%
# Combine existing weather data with newly extracted data
# -------------------------------------------------------
#complete_data = combine_data(weather_data, new_data)
complete_data = pd.concat([weather_data, new_data])
complete_data = complete_data.sort_values(by=['Date', 'Station', 'Time', 'Pressure'])
complete_data.head(-20)

# %%
print('Weather Data: {}\nMissing Data: {}\nNew Data: {}\nComplete Data: {}'
      .format(weather_data.size, len(missing_data), new_data.size, complete_data.size))

# %%
if True in complete_data.duplicated(subset=['Date', 'Station', 'Time', 'Pressure']).to_list():
    print("Duplicates Found")
    complete_data = complete_data.drop_duplicates(subset=['Date', 'Station', 'Time', 'Pressure'], keep='last')

# %%
print('Weather Data: {}\nMissing Data: {}\nNew Data: {}\nComplete Data: {}'
      .format(weather_data.size, len(missing_data), new_data.size, complete_data.size))

# %%
for index, row in complete_data.iterrows():
    print("{}\n".format(row))

# %% [markdown]
# ## Patch Dataset

# %%
# Patch dataset with nan values for any missing fields
# ----------------------------------------------------
final_data = patch_dataset(complete_data)
final_data = final_data.sort_values(by=['Date', 'Station', 'Time', 'Pressure'])
print("Final Data: {}".format(final_data.size))

# %%
final_data.head(-100)

# %% [markdown]
# ## Upload Data

# %%
# Upload clean data to bucket
# ---------------------------
upload_weather_data(complete_data)

# %%
# Up to 2020-03-27

# %% [markdown]
# ---
# # End
# ---
